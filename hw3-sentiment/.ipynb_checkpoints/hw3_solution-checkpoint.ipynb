# %%
import os
import numpy as np
import pickle
import random
import timeit

# %%
'''
Note:  This code is just a hint for people who are not familiar with text processing in python. There is no obligation to use this code, though you may if you like. 
'''


def folder_list(path,label):
    '''
    PARAMETER PATH IS THE PATH OF YOUR LOCAL FOLDER
    '''
    filelist = os.listdir(path)
    review = []
    for infile in filelist:
        file = os.path.join(path,infile)
        r = read_data(file)
        r.append(label)
        review.append(r)
    return review

def read_data(file):
    '''
    Read each file into a list of strings. 
    Example:
    ["it's", 'a', 'curious', 'thing', "i've", 'found', 'that', 'when', 'willis', 'is', 'not', 'called', 'on', 
    ...'to', 'carry', 'the', 'whole', 'movie', "he's", 'much', 'better', 'and', 'so', 'is', 'the', 'movie']
    '''
    f = open(file,encoding='UTF-8')
    lines = f.read().split(' ')
    symbols = '${}()[].,:;+-*/&|<>=~" '
    table = str.maketrans("a", "a", symbols)
    words = map(lambda Element: Element.translate(table).strip(), lines)
    words = filter(None, words)
    words = list(words)
    return words

###############################################
######## YOUR CODE STARTS FROM HERE. ##########
###############################################

def shuffle_data():
    '''
    pos_path is where you save positive review data.
    neg_path is where you save negative review data.
    '''
    pos_path = "/Users/twff/Downloads/machine_learning/hw/hw3-sentiment/data/pos"
    neg_path = "/Users/twff/Downloads/machine_learning/hw/hw3-sentiment/data/neg"
    
    pos_review = folder_list(pos_path,1)
    neg_review = folder_list(neg_path,-1)

    review = pos_review + neg_review
    random.seed(0)
    random.shuffle(review)
    pickle.dump(review, open("/Users/twff/Downloads/machine_learning/hw/hw3-sentiment/data/allreview.p", "wb" ) )

'''
Now you have read all the files into list 'review' and it has been shuffled.
Save your shuffled result by pickle.
*Pickle is a useful module to serialize a python object structure. 
*Check it out. https://wiki.python.org/moin/UsingPickle
'''
# Out:
# "\nNow you have read all the files into list 'review' and it has been shuffled.\nSave your shuffled result by pickle.\n*Pickle is a useful module to serialize a python object structure. \n*Check it out. https://wiki.python.org/moin/UsingPickle\n"

# %%
shuffle_data()

# %%
reviews = pickle.load(open("/Users/twff/Downloads/machine_learning/hw/hw3-sentiment/data/allreview.p", "rb" ) )
training_data = reviews[0:1500]
validation_data = reviews[1500:2000]
len(reviews)
# Out:
# 2000

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from collections import Counter
from nltk.corpus import stopwords
import nltk

def bag_of_words(words):
    '''
    words is a list of words
    -------------------
    count sparse bag of words representation.
    '''
    stop = set(stopwords.words('english'))
    words_stopfree = [w for w in words if w not in stop]
    count = Counter(words_stopfree[:-1])
    label = words[-1]
    return count, label

# %%
words=['hello','world','Hello','world','it','is','a','new','start', 1]
words, l = bag_of_words(words)

# %%
words
# Out:
# Counter({'Hello': 1, 'hello': 1, 'new': 1, 'start': 1, 'world': 2})

# %%
X_train  = []
y_train = []
for i in range(len(training_data)):
    words, label = bag_of_words(training_data[i])
    X_train.append(words)
    y_train.append(label)

# %%
training_data[1]
# Out:
# ['capsule',
#  'gal',
#  'is',
#  'a',
#  '50sish',
#  'london',
#  'cockney',
#  'gangster',
#  'who',
#  'has',
#  'retired',
#  'to',
#  'spain',
#  'his',
#  'old',
#  'associates',
#  'want',
#  'him',
#  'for',
#  'one',
#  'last',
#  'job',
#  'and',
#  'send',
#  'the',
#  'vicious',
#  'don',
#  'to',
#  'give',
#  'him',
#  'an',
#  'offer',
#  'he',
#  "can't",
#  'refuse',
#  'a',
#  'standout',
#  'performance',
#  'by',
#  'ben',
#  'kingsley',
#  'as',
#  'don',
#  'cannot',
#  'save',
#  'what',
#  'is',
#  'essentially',
#  'a',
#  'set',
#  'of',
#  'cliches',
#  'recycled',
#  'from',
#  'old',
#  'westerns',
#  '0',
#  '4',
#  'to',
#  '4',
#  'roger',
#  'ebert',
#  'asks',
#  'in',
#  'his',
#  'review',
#  'of',
#  'sexy',
#  'beast',
#  'who',
#  'would',
#  'have',
#  'guessed',
#  'that',
#  'the',
#  'most',
#  'savage',
#  'maddog',
#  'frothing',
#  'gangster',
#  'in',
#  'recent',
#  'movies',
#  'would',
#  'be',
#  'played',
#  'by',
#  'ben',
#  'kingsley',
#  '?',
#  'my',
#  'response',
#  'would',
#  'be',
#  'that',
#  'anyone',
#  'who',
#  'has',
#  'seen',
#  'alan',
#  'arkin',
#  'in',
#  'wait',
#  'until',
#  'dark',
#  'henry',
#  'fonda',
#  'in',
#  'once',
#  'upon',
#  'a',
#  'time',
#  'in',
#  'the',
#  'west',
#  'or',
#  'anthony',
#  'hopkins',
#  'in',
#  'the',
#  'silence',
#  'of',
#  'the',
#  'lambs',
#  'should',
#  'have',
#  'guessed',
#  'it',
#  'they',
#  'should',
#  'know',
#  'that',
#  'the',
#  'way',
#  'for',
#  'a',
#  'film',
#  'to',
#  'create',
#  'a',
#  'really',
#  'creepy',
#  'sociopath',
#  'is',
#  'cast',
#  'someone',
#  'who',
#  'generally',
#  'plays',
#  'mild',
#  'sympathetic',
#  'or',
#  'even',
#  'ineffectual',
#  'character',
#  'roles',
#  'the',
#  'same',
#  'characteristics',
#  'that',
#  'make',
#  'an',
#  'actor',
#  'seem',
#  'gentle',
#  'in',
#  'most',
#  'of',
#  'his',
#  'roles',
#  'can',
#  'work',
#  'in',
#  'his',
#  'favor',
#  'when',
#  'a',
#  'role',
#  'calls',
#  'for',
#  'him',
#  'to',
#  'be',
#  'fierce',
#  'and',
#  'vicious',
#  'that',
#  'is',
#  'the',
#  'principle',
#  'that',
#  'works',
#  'for',
#  'kingsley',
#  'in',
#  'sexy',
#  'beast',
#  'gary',
#  'gal',
#  'dove',
#  'played',
#  'by',
#  'ray',
#  'winstone',
#  'has',
#  'retired',
#  'from',
#  'a',
#  'london',
#  'career',
#  'of',
#  'crime',
#  'and',
#  'is',
#  'living',
#  'on',
#  'a',
#  'luxurious',
#  'villa',
#  'in',
#  'spain',
#  'life',
#  'has',
#  'become',
#  'a',
#  'routine',
#  'of',
#  'sunning',
#  'himself',
#  'and',
#  'relaxing',
#  'but',
#  'his',
#  'paradise',
#  'is',
#  'about',
#  'to',
#  'be',
#  'shattered',
#  'by',
#  'a',
#  'onetwopunch',
#  'the',
#  'first',
#  'punch',
#  'is',
#  'a',
#  'boulder',
#  'that',
#  'comes',
#  'rolling',
#  'down',
#  'the',
#  'hill',
#  'next',
#  'to',
#  'the',
#  'villa',
#  'the',
#  'second',
#  'punch',
#  'comes',
#  'from',
#  "gal's",
#  'past',
#  'back',
#  'in',
#  'london',
#  'gang',
#  'boss',
#  'teddy',
#  'bass',
#  'ian',
#  'mcshane',
#  "tv's",
#  'lovejoy',
#  'is',
#  'planning',
#  'to',
#  'break',
#  'into',
#  'a',
#  'safety',
#  'deposit',
#  'room',
#  'in',
#  'a',
#  'bank',
#  'and',
#  'he',
#  'wants',
#  'gal',
#  'he',
#  'sends',
#  'his',
#  'most',
#  'rabid',
#  'henchman',
#  'don',
#  'logan',
#  'ben',
#  'kingsley',
#  'to',
#  'fetch',
#  'gal',
#  'don',
#  'will',
#  'accept',
#  'any',
#  'decision',
#  'gal',
#  'makes',
#  'from',
#  'yes',
#  'to',
#  'certainly',
#  'however',
#  'if',
#  'gal',
#  'says',
#  'no',
#  'don',
#  'will',
#  'do',
#  'whatever',
#  'it',
#  'takes',
#  'to',
#  'turn',
#  'it',
#  'into',
#  'a',
#  'yes',
#  'including',
#  'threatening',
#  "guy's",
#  'exporn',
#  'star',
#  'wife',
#  'deedee',
#  'amanda',
#  'redman',
#  'in',
#  'the',
#  'meantime',
#  'don',
#  'knows',
#  'just',
#  'how',
#  'to',
#  'get',
#  'under',
#  "everybody's",
#  'skin',
#  'kingsley',
#  'makes',
#  'don',
#  'a',
#  'compact',
#  'package',
#  'of',
#  'fury',
#  'and',
#  'nastiness',
#  'there',
#  'are',
#  'some',
#  'serious',
#  'problems',
#  'in',
#  'louis',
#  "mellis's",
#  'and',
#  'david',
#  "scinto's",
#  'script',
#  'that',
#  'should',
#  'have',
#  'been',
#  'caught',
#  'before',
#  'filming',
#  'when',
#  'we',
#  'see',
#  'the',
#  'actual',
#  'crime',
#  'we',
#  'have',
#  'no',
#  'idea',
#  'why',
#  'gal',
#  'was',
#  'so',
#  'important',
#  'to',
#  'its',
#  'success',
#  'beyond',
#  'an',
#  'ability',
#  'to',
#  'use',
#  'skindiving',
#  'gear',
#  'no',
#  'special',
#  'talents',
#  'are',
#  'required',
#  'of',
#  'him',
#  'any',
#  'local',
#  'hood',
#  'could',
#  'have',
#  'done',
#  'what',
#  'gal',
#  'is',
#  'needed',
#  'for',
#  'additionally',
#  'the',
#  'crime',
#  'involves',
#  'digging',
#  'from',
#  'a',
#  'swimming',
#  'pool',
#  'to',
#  'the',
#  'bank',
#  'vault',
#  'flooding',
#  'the',
#  'vault',
#  'no',
#  'only',
#  'could',
#  'they',
#  'have',
#  'let',
#  'the',
#  'water',
#  'out',
#  'of',
#  'the',
#  'pool',
#  'and',
#  'avoided',
#  'the',
#  'complication',
#  'altogether',
#  'but',
#  'there',
#  'is',
#  'by',
#  'far',
#  'too',
#  'much',
#  'water',
#  'to',
#  'be',
#  'accounted',
#  'for',
#  'by',
#  'what',
#  'was',
#  'in',
#  'the',
#  'pool',
#  'in',
#  'spite',
#  'of',
#  'the',
#  'provocative',
#  'title',
#  'the',
#  'story',
#  'is',
#  'cliched',
#  'and',
#  'overly',
#  'familiar',
#  'i',
#  'know',
#  'i',
#  'have',
#  'seen',
#  'all',
#  'the',
#  'plot',
#  'elements',
#  'of',
#  'sexy',
#  'beast',
#  'in',
#  'old',
#  'westerns',
#  'like',
#  'the',
#  'law',
#  'and',
#  'jake',
#  'wade',
#  'the',
#  'story',
#  'is',
#  'usually',
#  'of',
#  'the',
#  'reformed',
#  'outlaw',
#  'a',
#  'robert',
#  'taylor',
#  'type',
#  'who',
#  'has',
#  'hung',
#  'up',
#  'his',
#  'guns',
#  'and',
#  'is',
#  'trying',
#  'for',
#  'a',
#  'life',
#  'of',
#  'peaceful',
#  'respectability',
#  'the',
#  'old',
#  'gang',
#  'however',
#  'wants',
#  'to',
#  'do',
#  'one',
#  'more',
#  'job',
#  'with',
#  'their',
#  'old',
#  'buddy',
#  'and',
#  'sends',
#  'a',
#  'rabid',
#  'richard',
#  'widmark',
#  'type',
#  'to',
#  'go',
#  'and',
#  'git',
#  '?',
#  'im',
#  'it',
#  'is',
#  'not',
#  'a',
#  'great',
#  'plot',
#  'in',
#  'sexy',
#  'beast',
#  'even',
#  'the',
#  'plot',
#  'twists',
#  'have',
#  'gray',
#  'beards',
#  'perhaps',
#  'the',
#  'film',
#  'has',
#  'a',
#  'little',
#  'more',
#  'respectability',
#  'because',
#  'it',
#  'was',
#  'made',
#  'not',
#  'as',
#  'a',
#  'western',
#  'but',
#  'as',
#  'a',
#  'stylish',
#  'british',
#  'gangster',
#  'film',
#  'it',
#  'is',
#  'an',
#  'old',
#  'plot',
#  'dressed',
#  'up',
#  'to',
#  'look',
#  'new',
#  'if',
#  'the',
#  'plot',
#  'is',
#  'old',
#  'at',
#  'least',
#  'the',
#  'style',
#  'is',
#  'creative',
#  'this',
#  'is',
#  'director',
#  'jonathan',
#  "glazer's",
#  'first',
#  'film',
#  'but',
#  'he',
#  'has',
#  'reputedly',
#  'done',
#  'some',
#  'notable',
#  'tv',
#  'ads',
#  'for',
#  'guinness',
#  'stout',
#  'his',
#  'style',
#  'does',
#  'have',
#  'some',
#  'unexpected',
#  'touches',
#  'including',
#  'some',
#  'very',
#  'odd',
#  'dream',
#  'sequences',
#  'cinematographer',
#  'ivan',
#  'bird',
#  'uses',
#  'a',
#  'lot',
#  'of',
#  'half',
#  'lit',
#  'scenes',
#  'we',
#  'see',
#  'one',
#  'side',
#  'of',
#  'a',
#  "person's",
#  'faces',
#  'but',
#  'the',
#  'other',
#  'side',
#  'fades',
#  'into',
#  'the',
#  'darkness',
#  'a',
#  'sort',
#  'of',
#  'metaphor',
#  'for',
#  'the',
#  'halfworld',
#  'these',
#  'characters',
#  'inhabit',
#  'half',
#  'of',
#  'everything',
#  'that',
#  'is',
#  'happening',
#  'is',
#  'also',
#  'kept',
#  'hidden',
#  'we',
#  'yanks',
#  'will',
#  'have',
#  'a',
#  'hard',
#  'time',
#  'with',
#  'some',
#  'of',
#  'the',
#  'dialog',
#  'at',
#  'least',
#  'in',
#  'my',
#  'theater',
#  'it',
#  'was',
#  'difficult',
#  'to',
#  'make',
#  'out',
#  'the',
#  'words',
#  'with',
#  'the',
#  'quiet',
#  'speaking',
#  'the',
#  'heavy',
#  'accents',
#  'and',
#  'the',
#  'cockney',
#  'language',
#  'sexy',
#  'beast',
#  'is',
#  'a',
#  'very',
#  'and',
#  'familiar',
#  'minor',
#  'plot',
#  'lent',
#  'respectability',
#  'in',
#  'the',
#  'us',
#  'by',
#  'being',
#  'done',
#  'in',
#  'what',
#  'is',
#  'here',
#  'a',
#  'still',
#  'somewhat',
#  'novel',
#  'genre',
#  'the',
#  'london',
#  'crime',
#  'film',
#  'the',
#  'plot',
#  'may',
#  'be',
#  'new',
#  'to',
#  'british',
#  'crime',
#  'films',
#  'but',
#  'it',
#  'would',
#  'be',
#  'overly',
#  'familiar',
#  'as',
#  'a',
#  'western',
#  'further',
#  'respectability',
#  'comes',
#  'from',
#  'ben',
#  "kingsley's",
#  'highpowered',
#  'performance',
#  'i',
#  'give',
#  'it',
#  'a',
#  '4',
#  'on',
#  'the',
#  '0',
#  'to',
#  '10',
#  'scale',
#  'and',
#  'a',
#  '0',
#  'on',
#  'the',
#  '4',
#  'to',
#  '4',
#  'scale',
#  -1]

# %%
X_valid  = []
y_valid = []
for i in range(len(validation_data)):
    words, label = bag_of_words(validation_data[i])
    X_valid.append(words)
    y_valid.append(label)

# %%
print(X_train[10])
# Out:
# Counter({'the': 31, 'to': 16, 'and': 16, 'a': 15, 'of': 15, 'in': 6, 'as': 6, 'from': 6, 'with': 6, 'is': 5, 'are': 5, 'we': 4, 'most': 4, 'have': 4, 'ghosts': 4, 'hand': 4, 'mars': 4, 'convenient': 4, 'even': 3, 'cube': 3, 'one': 3, 'for': 3, 'all': 3, 'has': 3, 'this': 3, 'that': 3, 'but': 3, 'only': 3, 'dynamite': 3, 'when': 3, 'characters': 3, 'they': 2, 'residents': 2, 'ice': 2, 'zombie': 2, 'moments': 2, 'tell': 2, 'our': 2, 'so': 2, 'conveniently': 2, 'you': 2, 'taken': 2, 'by': 2, 'my': 2, 'story': 2, 'machine': 2, 'future': 2, 'williams': 2, 'her': 2, 'bad': 2, 'fun': 2, 'forced': 2, 'on': 2, 'film': 2, 'convenience': 2, '?': 2, 'life': 2, 'off': 2, 'remote': 2, 'travel': 1, 'supply': 1, 'road': 1, 'itself': 1, 'its': 1, 'though': 1, 'bronx': 1, 'needs': 1, 'heads': 1, 'trial': 1, 'armored': 1, 'stopping': 1, 'killing': 1, 'be': 1, 'may': 1, "film's": 1, 'kids': 1, 'me': 1, 'sent': 1, 'fate': 1, 'lopped': 1, 'tough': 1, 'ripped': 1, 'dubbed': 1, 'reminisces': 1, 'simplicity': 1, 'minor': 1, 'commander': 1, 'way': 1, 'packs': 1, 'back': 1, 'things': 1, 'past': 1, 'good': 1, 'natasha': 1, 'other': 1, 'end': 1, 'loves': 1, 'rare': 1, 'martian': 1, 'sequences': 1, 'cell': 1, 'out': 1, 'every': 1, 'viewpoint': 1, 'gotten': 1, 'long': 1, 'time': 1, 'alien': 1, 'streetwise': 1, 'supporting': 1, 'comrades': 1, 'movie': 1, 'carpenter': 1, 'flashessideways': 1, 'henstridge': 1, 'better': 1, 'why': 1, 'beats': 1, 'set': 1, 'placed': 1, 'team': 1, 'taught': 1, 'stars': 1, 'certainly': 1, 'nukes': 1, '24hour': 1, 'alienpossessed': 1, 'station': 1, 'supplying': 1, 'uppity': 1, 'development': 1, 'guaranteed': 1, 'lends': 1, 'heavily': 1, 'escape': 1, 'detonation': 1, 'get': 1, 'slushee': 1, 'cop': 1, 'discover': 1, 'nuclear': 1, 'handle': 1, 'warrior': 1, 'storytelling': 1, 'character': 1, 'control': 1, 'another': 1, 'about': 1, 'keeps': 1, 'constructed': 1, 'bit': 1, 'cool': 1, 'decapitating': 1, 'was': 1, 'guy': 1, 'tnt': 1, 'at': 1, 'anyway': 1, "can't": 1, 'know': 1, 'dispensed': 1, 'lovely': 1, 'darkest': 1, 'guns': 1, 'which': 1, 'love': 1, 'an': 1, 'mining': 1, 'beloved': 1, 'whatever': 1, 'brother': 1, 'nails': 1, 'entertainment': 1, 'retrieve': 1, 'will': 1, 'john': 1, 'straight': 1, 'instead': 1, 'lose': 1, 'nothing': 1, 'accent': 1, 'die': 1, 'lesson': 1, 'them': 1, 'atm': 1, 'what': 1, 'remaining': 1, 'far': 1, 'leaps': 1, 'man': 1, 'appropriately': 1, 'keeping': 1, 'poorly': 1, '1970s': 1, "we're": 1, 'use': 1, 'gets': 1, 'plenty': 1, 'changes': 1, 'were': 1, 'decided': 1, 'indeed': 1, 'yet': 1, 'heartily': 1, 'phone': 1, 'easily': 1, 'sacrificing': 1, 'action': 1, "cop's": 1, 'wisdom': 1, 'headchopping': 1, 'around': 1, 'filled': 1, 'roles': 1, 'gun': 1, 'rifles': 1, 'perhaps': 1, 'after': 1, 'comparing': 1, 'ridiculously': 1, 'town': 1, 'culture': 1, 'illconceived': 1, 'police': 1, 'kill': 1, 'invented': 1, 'hapless': 1, 'eventually': 1, 'tribunal': 1, 'accessible': 1, "pillpoppin'": 1, 'space': 1, 'welltrained': 1, "town's": 1, 'come': 1, 'than': 1, 'defines': 1, 'narcotics': 1, 'dialogue': 1, 'zombiestomping': 1, 'incomprehensible': 1, 'eventempered': 1, 'home': 1, 'train': 1, 'attempts': 1, 'or': 1, 'anything': 1, 'sheer': 1, 'his': 1, 'present': 1, 'clutches': 1, 'say': 1, 'up': 1, 'if': 1, 'cap': 1, 'us': 1, 'she': 1, 'stick': 1, 'transportation': 1, 'stolen': 1, 'idiotic': 1, 'should': 1, 'next': 1, 'conquer': 1, 'thing': 1, 'immunity': 1, 'few': 1, 'becoming': 1, 'ritually': 1, 'explosions': 1, 'crime': 1, 'kwikemart': 1, 'pages': 1, 'pronounces': 1, 'healthy': 1, 'these': 1, 'overuse': 1, 'flashbacks': 1, "don't": 1, 'rookies': 1, 'america': 1, 'mess': 1, 'demolition': 1, 'yes': 1, 'run': 1, 'slaughtered': 1, 'street': 1, 'actually': 1, 'care': 1, 'interaction': 1, "residents'": 1, 'mishmash': 1, 'moment': 1, 'squadron': 1, 'apparently': 1})

# %%
def dotProduct(d1, d2):
    """
    @param dict d1: a feature vector represented by a mapping from a feature (string) to a weight (float).
    @param dict d2: same as d1
    @return float: the dot product between d1 and d2
    """
    if len(d1) < len(d2):
        return dotProduct(d2, d1)
    else:
        return sum(d1.get(f, 0) * v for f, v in d2.items())

def increment(d1, scale, d2):
    """
    Implements d1 += scale * d2 for sparse vectors.
    @param dict d1: the feature vector which is mutated.
    @param float scale
    @param dict d2: a feature vector.

    NOTE: This function does not return anything, but rather
    increments d1 in place. We do this because it is much faster to
    change elements of d1 in place than to build a new dictionary and
    return it.
    """
    for f, v in d2.items():
        d1[f] = d1.get(f, 0) + v * scale

def mutiply(scale, d):
    """
    Implements d1 += scale * d2 for sparse vectors.
    @param dict d1: the feature vector which is mutated.
    @param float scale
    @param dict d2: a feature vector.

    NOTE: This function does not return anything, but rather
    increments d1 in place. We do this because it is much faster to
    change elements of d1 in place than to build a new dictionary and
    return it.
    """
    for f, v in d.items():
        d[f] = d.get(f, 0) + v * scale
    return d

# %%
dotProduct(X_train[1], {})
# Out:
# 0

# %%
def pegasos_svm(X, y, Lambda, num_iter):
    '''
    X is input sparse data representation
    y is pos and neg label of the review
    Lambda is parameter of step size
    num_iter is number of epoch
    ----------------------------
    w is sparse weight vector
    '''
    w = {}
    t = 0.0
    
    for i in range(num_iter):
        start = timeit.default_timer()
        for j in range(len(X)):
            #w_old = w.copy()
            t = t + 1
            alpha = 1 / (t * Lambda)
            if (y[j] * dotProduct(w, X[j])) < 1:
                #for k, v in w.items():
                 #   w[k] = w.get(k, 0) + v * (1-alpha * Lambda)
                increment(w, -alpha * Lambda, w)
                increment(w, alpha*y[j], X[j])
            else:
                increment(w, -alpha * Lambda, w)
        stop = timeit.default_timer()
        print('The time of the {} epoch is {}'.format(i+1,(stop-start)))
    return w

# %%
w = pegasos_svm(X_train, y_train, Lambda=10, num_iter=20)
# Out:
# The time of the 1 epoch is 16.7350112109998
# The time of the 2 epoch is 26.042331717995694
# The time of the 3 epoch is 24.68780592099938
# The time of the 4 epoch is 24.562127457000315
# The time of the 5 epoch is 24.870430830997066
# The time of the 6 epoch is 24.874173132993747
# The time of the 7 epoch is 24.774511045994586
# The time of the 8 epoch is 24.73381142700964
# The time of the 9 epoch is 24.740555381999002
# The time of the 10 epoch is 24.77694539199001
# The time of the 11 epoch is 24.742912389003322
# The time of the 12 epoch is 25.24772353300068
# The time of the 13 epoch is 29.86519856999803
# The time of the 14 epoch is 25.101484796003206
# The time of the 15 epoch is 26.183572648995323
# The time of the 16 epoch is 26.148424128987244
# The time of the 17 epoch is 27.446792246002587
# The time of the 18 epoch is 27.99856451099913
# The time of the 19 epoch is 29.490715571999317
# The time of the 20 epoch is 26.211274907007464

# %%
def pegasos_svm_change(X, y, Lambda, num_iter):
    '''
    X is input sparse data representation
    y is pos and neg label of the review
    Lambda is parameter of step size
    num_iter is number of epoch
    ----------------------------
    w is sparse weight vector
    '''
    s =1
    W = {}
    t = 0.0
    w = {}
    #print(type(W))
    
    for i in range(num_iter):
        start = timeit.default_timer()
        for j in range(len(X)):
            t = t + 1
            alpha = 1 / (t * Lambda)
            s = (1 - Lambda * alpha)*s
            if s == 0:
                s = 1
                W = {}  
            if y[j] * s * dotProduct(W, X[j]) < 1:
                increment(W, (1/s)*alpha*y[j], X[j])
            else:
                W = W
        stop = timeit.default_timer()
        print('The time of the {} epoch is {}'.format(i+1,(stop-start)))
    print(s)
    increment(w,s,W)
    return w

# %%
w = pegasos_svm_change(X_train, y_train, Lambda=10, num_iter=20)
# Out:
# The time of the 1 epoch is 0.3885569639969617
# The time of the 2 epoch is 0.37763888500921894
# The time of the 3 epoch is 0.43433662499592174
# The time of the 4 epoch is 0.36520389399083797
# The time of the 5 epoch is 0.3710629899869673
# The time of the 6 epoch is 0.3578811479965225
# The time of the 7 epoch is 0.3565807289996883
# The time of the 8 epoch is 0.39485841400164645
# The time of the 9 epoch is 0.3906846549944021
# The time of the 10 epoch is 0.3692717780068051
# The time of the 11 epoch is 0.4183165559952613
# The time of the 12 epoch is 0.38175947799754795
# The time of the 13 epoch is 0.3617392349988222
# The time of the 14 epoch is 0.3653940619988134
# The time of the 15 epoch is 0.41751101799309254
# The time of the 16 epoch is 0.392883830005303
# The time of the 17 epoch is 0.36920433399791364
# The time of the 18 epoch is 0.3847044510039268
# The time of the 19 epoch is 0.3717086569959065
# The time of the 20 epoch is 0.39212347198917996
# 3.333333333333299e-05

# %%
w
# Out:
# {'thankless': 3.053113317719182e-20,
#  'victorious': 0.00019999999999999998,
#  'specialised': -0.00015999999999999999,
#  'courtesy': 0.00019999999999999998,
#  'accounts': -0.0006100000000000002,
#  'stretch': -0.0004000000000000001,
#  'sonar': 0.0002,
#  'netsurfing': -0.0002,
#  'recreate': 0.0004,
#  'city': 0.003389999999999995,
#  'infidelities': 3e-05,
#  'piles': -0.0008000000000000006,
#  'mugs': -0.00019999999999999998,
#  'omnipresence': 0.00019999999999999993,
#  'singles': -0.0002,
#  'postmodern': 0.00019999999999999998,
#  'foreseeable': -1.8041124150158802e-20,
#  'patheticallywritten': -0.00019999999999999998,
#  'multiday': 0.00039999999999999996,
#  'pseudofeminist': -0.0002,
#  'interacting': 3e-05,
#  'woodsboro': -0.00019999999999999998,
#  'armor': 0.0009999999999999998,
#  'darkside': 0.0002,
#  'parrot': -0.0004,
#  'tangentially': 0.0002,
#  'complicates': -0.0003999999999999999,
#  'shift': -0.0005999999999999998,
#  'writersdirectors': 0.00020000000000000004,
#  'socks': 1.3877787807814463e-21,
#  'navy': -0.0007199999999999998,
#  'displaying': 0.0011999999999999982,
#  'invade': 0.00018999999999999998,
#  'shotgun': -0.0007199999999999999,
#  'bite': -0.00020000000000000004,
#  'witt': -0.0001999999999999999,
#  'blackandwhite': 0.00019999999999999998,
#  'hook': -0.0008000000000000004,
#  'fortunes': 0.00019999999999999998,
#  'donor': -0.00019999999999999993,
#  "princess'": 0.0002,
#  'channels': 0.0004,
#  'gu': 0.0004000000000000001,
#  'minimize': -0.00020000000000000004,
#  'develops': 0.00039999999999999986,
#  'discusses': 0.00020000000000000004,
#  'additional': 0.0006000000000000002,
#  'macneill': 0.00019999999999999998,
#  'witted': -0.0002,
#  'semiautomatic': -0.0002,
#  'postproduction': -0.00039000000000000005,
#  'imprisoned': 0.00039999999999999996,
#  'arrivals': 0.00019999999999999998,
#  'nearing': 0.00020000000000000004,
#  'timo': 0.00020000000000000004,
#  'closeddown': -0.00019999999999999998,
#  'provocative': -0.0004000000000000001,
#  'molasses': -0.0004,
#  'invaluable': -0.00019999999999999998,
#  'key': -0.00041999999999999985,
#  'introducing': -0.00014000000000000001,
#  '40yearold': 0.00019999999999999993,
#  'hunt': 0.0015999999999999992,
#  "up's": -0.0002,
#  'wanker': -0.00020000000000000004,
#  'meshes': 0.00019999999999999998,
#  "o'neill": 5.551115123125785e-21,
#  'tick': 0.00039,
#  'regular': 0.00038,
#  'attentiveness': 0.00019999999999999998,
#  'wallowing': -0.0002,
#  'sober': -0.0003999999999999999,
#  'mouthing': 0.00019999999999999996,
#  'codenamed': -0.00020000000000000004,
#  'cassidy': 0.00020000000000000006,
#  'krays': -0.00019999999999999996,
#  'bagpipes': 0.0002,
#  'tattoos': -0.00019999999999999998,
#  'enlist': 0.0004,
#  'borrow': -0.0002,
#  'incorporated': -0.00019999999999999998,
#  'railroad': -0.0004,
#  'monosyllables': 0.00019999999999999996,
#  "rector's": -0.00019999999999999996,
#  "sisters'": -0.00019999999999999998,
#  'asset': -0.00020000000000000004,
#  'bananas': -1.3877787807814463e-21,
#  'armin': 0.0006000000000000001,
#  'scatological': 0.0002,
#  'thorough': 0.0004,
#  "majesty's": 0.0002,
#  'pacing': 0.0014,
#  'video': -0.004850000000000026,
#  "'what": 0.0002,
#  'hipness': -0.0002,
#  'entertainingly': -0.00020000000000000004,
#  'doodoo': 0.00019999999999999998,
#  'pryor': -0.00020000000000000004,
#  'brilliantly': 0.0007900000000000001,
#  'pitchfork': 0.00019999999999999993,
#  'spider': -0.00039999999999999996,
#  "who've": -2.4980018054066034e-20,
#  'ended': -0.00082,
#  'ghostbusters': -1.3877787807814463e-21,
#  'fistfight': -0.00019999999999999998,
#  'informed': -1.110223024625157e-20,
#  'grail': 0.0004,
#  'attic': -0.0005999999999999998,
#  'robicheaux': -0.0002,
#  'cheerleader': 0.0005800000000000001,
#  'graham': 0.0028200000000000018,
#  'thematic': 0.0007900000000000003,
#  'lifeless': -0.00039999999999999986,
#  'aristocracy': 0.0002,
#  'rhea': -0.00039999999999999996,
#  'estefan': 0.00019999999999999998,
#  'lung': 0.00017999999999999996,
#  'intercom': -0.00019999999999999996,
#  'augmented': -0.0002,
#  'problemsolving': 0.0002,
#  'rocksolid': -9.999999999999997e-06,
#  'highflying': -0.0002,
#  "'comedy": -0.00019999999999999998,
#  'att': -0.00068,
#  'fewer': -0.00020000000000000004,
#  "sethe's": 0.0012,
#  'tourist': -0.00020000000000000004,
#  'delving': -6.938893903907232e-21,
#  'divvy': -0.00019999999999999996,
#  'y2k': -0.0004,
#  '19th': 0.0008,
#  'shalt': -0.00039999999999999996,
#  'statements': 0.00020999999999999993,
#  'mold': 1.3877787807814463e-21,
#  'indescribable': 0.00019999999999999998,
#  'julia': 0.0012099999999999997,
#  'sermon': -0.00019999999999999996,
#  'chord': 0.00046999999999999977,
#  'crippen': -0.00019999999999999998,
#  'firefighting': -0.0004,
#  'charms': 0.0005999999999999998,
#  'casts': -0.0002,
#  'amoral': -0.0007799999999999999,
#  'travis': 3.8857805861880497e-20,
#  'subplot': -0.0019800000000000004,
#  'seeks': 0.0008,
#  'concentration': 0.0005999999999999998,
#  'override': -0.00019999999999999996,
#  'yanne': -0.0002,
#  'reduce': -1.526556658859591e-20,
#  'twelve': -0.00019999999999999993,
#  'mom': -1.3877787807814463e-20,
#  'dropoffs': 0.00019999999999999998,
#  'induced': 0.00019999999999999998,
#  'plague': -0.0009999999999999998,
#  'takenocrap': -0.00020000000000000004,
#  'biological': -0.0002,
#  'oscarwinning': -0.00020000000000000004,
#  'brody': 0.0011999999999999995,
#  'illegally': 1.526556658859591e-20,
#  "moment's": 0.00019999999999999998,
#  'ordeals': 0.00019999999999999998,
#  'tea': -0.0009999999999999998,
#  'regulars': -0.00020000000000000004,
#  'jacobi': 0.00020000000000000004,
#  'sleepyvoiced': 0.0002,
#  'contacted': 0.00018999999999999996,
#  "floats'": 0.0002,
#  'epa': -0.00019999999999999996,
#  'tightly': -0.00015000000000000004,
#  'stoned': -0.00025999999999999987,
#  'wcw': -0.0008,
#  'scary': 0.0004099999999999998,
#  'throats': 0.00019999999999999996,
#  'menendez': 0.00019999999999999996,
#  'compliments': 0.0004000000000000001,
#  'typecast': 7.000000000000002e-05,
#  'reasonable': -0.0004000000000000001,
#  'hadnut': 0.00019999999999999993,
#  'elephant': 0.0005999999999999998,
#  'goofing': 0.00020000000000000004,
#  'selfirony': -0.00019999999999999998,
#  'lauri': 0.0012,
#  'goldie': -0.00020000000000000004,
#  'pressed': -0.00019999999999999996,
#  '_must_': -0.0002,
#  'hooded': 0.00019,
#  'waning': 0.0002,
#  'malone': -0.0004,
#  'pretension': -0.00019999999999999998,
#  'transaction': -0.00020000000000000004,
#  "individual's": 0.00020999999999999998,
#  'alcoholism': -1.2490009027033017e-20,
#  'offers': -0.0007800000000000007,
#  'newsradio': -0.00019999999999999998,
#  'credibilityin': 0.0002,
#  'psychically': 0.0002,
#  'handled': -0.00041000000000000005,
#  'flashy': 0.0001999999999999999,
#  'overdramatic': -0.0004000000000000001,
#  'agreement': 0.0005899999999999998,
#  'showy': 0.0008100000000000003,
#  'horrid': -0.0008000000000000001,
#  'olivier': 0.00020000000000000004,
#  'quite': 0.004000000000000015,
#  'ben': 0.0008300000000000001,
#  'jovial': 0.0002,
#  'harsh': 0.0008600000000000003,
#  'motherly': -8.326672684688678e-21,
#  'matilda': -0.0012000000000000001,
#  'guts': -0.0011999999999999988,
#  'movements': 0.0006,
#  'kilter': -0.00020000000000000004,
#  'breed': -0.0013999999999999996,
#  'enough': -0.007080000000000003,
#  'palace': 0.00039999999999999996,
#  'sloppily': -0.0004000000000000001,
#  "viewer's": 3.0000000000000035e-05,
#  'deciphering': -0.0002,
#  'coverage': 0.0002,
#  'frank': -0.00022999999999999982,
#  'effect': -0.0011499999999999993,
#  'seemed': -0.00037000000000000043,
#  '?': -0.03029000000000027,
#  'celebrity': -0.0008000000000000001,
#  'directorial': 0.0008000000000000004,
#  'read': 1.4016565685892608e-19,
#  'hacked': 4.163336342344339e-21,
#  'institutions': 0.0002,
#  'wrongagain': 0.00019999999999999998,
#  'panic': 0.00039999999999999986,
#  'horn': -0.0004000000000000001,
#  'mickelberry': -0.0002,
#  'definitions': 0.00018999999999999998,
#  'shea': -0.00019999999999999996,
#  "'f": 0.00019999999999999998,
#  "woody's": 0.0002,
#  'outlined': -0.00019999999999999996,
#  'ostensibly': -0.0008000000000000004,
#  'earnesttoafault': -0.00020000000000000004,
#  'fullcircle': 0.00018999999999999998,
#  'health': -0.00019999999999999996,
#  'jarjar': 0.00019999999999999996,
#  "romero's": 0.00019999999999999998,
#  'croatia': 0.00039999999999999996,
#  'suicide': -2.0000000000000052e-05,
#  'aisle': 0.0004,
#  'perfects': -0.00020000000000000004,
#  '1968': 0.0008,
#  'washed': -1.526556658859591e-20,
#  'heeere': -0.00019999999999999998,
#  'captured': 0.0008000000000000004,
#  'elite': 0.0002,
#  'touching': 0.0019600000000000012,
#  'takes': 0.002640000000000003,
#  'productplacement': -0.0002,
#  'moreover': -0.00014000000000000001,
#  'villiage': 0.00020000000000000004,
#  'policy': -1.3877787807814463e-21,
#  'im': -0.00019999999999999998,
#  'vindictive': -0.00039999999999999996,
#  'fred': 0.0006500000000000001,
#  'duddy': 0.0002,
#  'plagiarist': -0.00019999999999999996,
#  'overarching': 0.00018999999999999998,
#  'trainerconsultant': -0.00019999999999999998,
#  'criticisms': 0.00021,
#  'gains': 0.0008000000000000006,
#  'frieberg': 0.00019999999999999998,
#  'avoid': -0.0011899999999999986,
#  'mustafa': 0.00019999999999999998,
#  'plausibility': -0.00019999999999999998,
#  'digs': 0.0004299999999999998,
#  'pointless': -0.0007600000000000004,
#  'flyboy': -0.00020000000000000004,
#  'pintsized': 0.00019999999999999998,
#  'exotically': 9.999999999999997e-06,
#  'emmerich': 0.00019999999999999996,
#  'reshoots': 0.0002,
#  'satirizing': -0.00020000000000000004,
#  'berdan': 0.00020000000000000004,
#  'klendathu': 3.0000000000000028e-05,
#  'jamey': 0.00039999999999999996,
#  'props': -0.00039999999999999996,
#  "browne's": 9.999999999999997e-06,
#  'parole': -0.001,
#  'steady': 0.0008000000000000004,
#  "helen's": -0.0004000000000000001,
#  'giamatti': 0.00019999999999999993,
#  'awaits': 0.00019999999999999998,
#  'tortured': 0.0005799999999999998,
#  'assortment': -0.0005999999999999998,
#  'resembling': -0.00020999999999999987,
#  'unexplained': 0.0003900000000000001,
#  'sage': 0.00019,
#  'select': 0.0002,
#  'alice': 0.00039,
#  'cheer': 0.0004000000000000001,
#  'germane': 0.0002,
#  'sweep': 1.9428902930940248e-20,
#  'honor': 0.0019599999999999995,
#  'male': 2.0000000000000012e-05,
#  'sl': 0.0002,
#  "reiner's": -0.0002,
#  'downy': 0.0004,
#  'switzerland': -0.00019999999999999998,
#  'welfare': 0.0002,
#  'curtis': 0.0003900000000000001,
#  'fbi': -0.0012499999999999994,
#  'newfoundland': -0.0006,
#  'dollops': -0.00019999999999999998,
#  'grow': 0.0010599999999999984,
#  'flagging': 0.00019999999999999996,
#  'sorcerer': 0.00020000000000000004,
#  'weirdness': 0.00020000000000000006,
#  'cocky': 0.0006000000000000003,
#  "perry's": -0.0002,
#  'posess': 0.00019999999999999998,
#  "they're": -0.005070000000000019,
#  'courts': 0.0004,
#  'lofty': 9.999999999999997e-06,
#  'noises': -0.0008000000000000001,
#  'madly': 6.938893903907232e-21,
#  'basis': 7.216449660063521e-20,
#  "jo's": 0.0006,
#  'criminal': 0.00107,
#  'reenactment': -0.00019999999999999993,
#  'gungho': 0.0004,
#  'tearjerker': 0.0005999999999999998,
#  'landed': 0.0005999999999999998,
#  'silverware': -0.00034,
#  'governmentcontrolled': -0.00019999999999999998,
#  'soiled': 0.0002,
#  "satan's": -0.0002,
#  'mounts': -0.0002,
#  'shoreline': 0.00019999999999999998,
#  'mispronouncing': -0.00019999999999999998,
#  'malkovich': 0.0010000000000000005,
#  'classical': 0.0008000000000000001,
#  'aboriginal': 0.0005699999999999999,
#  'determined': 0.0006300000000000001,
#  'alias': -0.0005999999999999998,
#  '8': 0.001399999999999997,
#  'fireman': -0.00019999999999999998,
#  'omnipotent': 0.0004000000000000001,
#  'kotter': 0.0004,
#  'priestess': -0.00020000000000000004,
#  'salma': -0.0002000000000000001,
#  'uninterestingly': -0.0002,
#  'females': 8.326672684688678e-21,
#  'thankful': -0.0002,
#  'judd': -0.0015999999999999994,
#  'antimilitary': 0.0002,
#  'previews': -0.00011000000000000002,
#  'consider': -1.0547118733938992e-19,
#  'vegetarianism': 0.00019999999999999998,
#  'cartoonish': 0.00018999999999999993,
#  'facet': -0.00020000000000000004,
#  'clueless': -0.001399999999999999,
#  'motif': -0.00019999999999999996,
#  'windsor': -0.0003999999999999999,
#  'frustrations': 0.00019999999999999998,
#  'hailed': 0.00039000000000000005,
#  'notion': -0.001,
#  'smalltobigscreen': -0.00019999999999999998,
#  'watch': -0.0015700000000000015,
#  'surfer': 0.00020000000000000004,
#  'cliched': -0.00015999999999999999,
#  'truck': -0.0004000000000000003,
#  'largebreasted': 0.00019999999999999996,
#  'hanged': -0.00039999999999999996,
#  'starved': 0.00020000000000000004,
#  'wow': 0.00039999999999999996,
#  'appearances': -1.2490009027033017e-20,
#  "crock's": -0.00020000000000000004,
#  'scowls': 0.00018999999999999998,
#  'amberlike': 0.0002,
#  'telepathic': -0.00034,
#  'nicolodi': 0.0002,
#  'welltodo': 0.0005999999999999998,
#  'disagree': 0.00018999999999999998,
#  'smiling': -2.0816681711721695e-20,
#  'grandmother': 0.0006000000000000001,
#  'asserting': 0.00019,
#  'siamese': -0.00020000000000000004,
#  'kong': -0.0006199999999999999,
#  "makers'": -0.00019999999999999998,
#  'dodging': -0.00020000000000000004,
#  'chores': 0.00020000000000000004,
#  'pace': 0.0025800000000000107,
#  "kimba's": 0.00019999999999999998,
#  'bebe': 0.00020000000000000004,
#  'bestseller': 0.00023000000000000003,
#  'assorted': -0.00039999999999999996,
#  "mib's": 0.00020000000000000004,
#  'entitled': 0.00019999999999999998,
#  'cholera': 0.00019999999999999996,
#  'based': 0.0014199999999999914,
#  'ving': -0.0006000000000000001,
#  'eamonn': 0.0002,
#  'richie': -0.0002,
#  'allegorical': 0.00019999999999999993,
#  'barkeep': -0.00020000000000000004,
#  'directional': 0.0002,
#  'altered': -0.00019999999999999993,
#  'overcome': 0.0005800000000000001,
#  'excellence': -0.00019999999999999993,
#  'batgirl': -0.0006000000000000001,
#  'topic': -0.0006,
#  '`have': -0.00019999999999999998,
#  'allencompassing': 0.0002,
#  'scenechewing': -0.00020000000000000004,
#  'depart': 0.0002,
#  'reversal': 0.001,
#  'unremarkable': 0.0004000000000000001,
#  'darned': -0.0004,
#  'thwarts': -0.0002,
#  'european': -0.0003900000000000001,
#  'conveying': -0.00021,
#  'unfortunates': 0.00019999999999999998,
#  'customary': 0.0005999999999999997,
#  '`i': 0.00019999999999999998,
#  'disrespect': -0.0002,
#  'bastard': 0.0005900000000000002,
#  'amounts': -0.00020000000000000006,
#  'restless': 0.00019,
#  'represented': -0.00039999999999999996,
#  'pertains': 0.00021,
#  'oncetalented': -0.00019999999999999996,
#  'transition': -3.747002708109905e-20,
#  'emerging': 0.00019999999999999998,
#  'jeanne': 0.00020000000000000028,
#  'casey': 0.0006,
#  'control': -0.001059999999999999,
#  'mid': 0.0004,
#  'bigglesworth': 0.00019999999999999998,
#  '247': 0.00020000000000000004,
#  'underwood': -0.0002,
#  'exclusive': 0.00039999999999999986,
#  'cliche': -0.0013999999999999987,
#  'steve': -0.00020000000000000004,
#  'squeeze': 6.938893903907232e-21,
#  'abolitionists': 0.0004,
#  'tortoise': -0.0002,
#  'odette': -0.0006000000000000001,
#  'simpsons': 0.00019999999999999998,
#  'escalating': 0.0002,
#  'ab': -0.00020000000000000004,
#  'stories': 0.0037000000000000075,
#  'rewire': 0.00019999999999999998,
#  'confession': 0.00019,
#  'novelistic': 0.0004000000000000001,
#  'backward': -0.00020000000000000004,
#  'antivampire': 0.00020000000000000004,
#  'reprogramming': -0.00020000000000000004,
#  'sexromp': -0.00020000000000000004,
#  'finn': -0.002,
#  "labute's": -0.00042999999999999994,
#  'modernist': 0.00019999999999999998,
#  'targeted': -0.0002,
#  'definitive': -3.6082248300317604e-20,
#  'mcmahon': -0.0004,
#  '16': 0.0006099999999999999,
#  'improvise': 0.00019999999999999998,
#  'probgram': -0.00019999999999999998,
#  'legal': 0.002400000000000002,
#  'incrowd': -0.0003999999999999999,
#  "japan's": 0.00020000000000000004,
#  'storh': -0.00019999999999999998,
#  'kindly': 0.0008000000000000004,
#  'l': 0.0018000000000000002,
#  'obsesses': 0.00020000000000000004,
#  'sena': -0.0002,
#  'burstyn': 0.00039999999999999996,
#  'contained': -0.0005099999999999997,
#  'fraught': 0.00018999999999999998,
#  'enola': -0.0007999999999999998,
#  'affecting': 0.00039999999999999996,
#  'owens': 0.0006,
#  'liveaction': -0.0008000000000000001,
#  'eyefilling': 0.00019999999999999998,
#  'portent': 0.0002,
#  'lousy': -0.0020000000000000018,
#  'pseudomorbidity': 9.999999999999997e-06,
#  'purple_': 0.00020000000000000004,
#  'privy': 0.0004,
#  'wroth': -0.00019999999999999996,
#  'changeofpace': 0.00020000000000000004,
#  'banality': -0.0004,
#  'hiller': -0.0004000000000000001,
#  'hoodlums': -0.00019999999999999996,
#  "day'": 0.00020000000000000004,
#  'bookie': 6.938893903907232e-21,
#  'propositions': -0.00019999999999999998,
#  'tour': 0.0007900000000000002,
#  'glorious': -0.0002,
#  'menstruating': -0.00019999999999999996,
#  'mic': -0.00019999999999999998,
#  'caton': 0.0002,
#  'sez': -0.0002,
#  'companionability': 0.00020000000000000006,
#  'looked': -0.0029600000000000004,
#  'slunk': -0.00020000000000000004,
#  'vile': -0.00019999999999999998,
#  'sisters': -0.00019999999999999998,
#  'tammy': -0.00019999999999999998,
#  'smuggled': 0.00020000000000000004,
#  'blythe': -0.0004000000000000001,
#  'fumble': -0.00019999999999999993,
#  'mediums': -0.00020000000000000004,
#  'exhibition': -0.0002,
#  'ought': 0.00040000000000000013,
#  'landscaping': 0.0002,
#  'taxed': 0.0002,
#  'pillsbury': -0.00068,
#  "might've": -0.0008000000000000001,
#  'handed': 0.0005999999999999997,
#  'solos': 0.0002,
#  'resides': -0.0002,
#  'modem': 0.0005999999999999998,
#  'tapping': -0.0002,
#  'view': 0.0017999999999999993,
#  'port': -1.6653345369377356e-20,
#  'stereotypical': -0.0011999999999999986,
#  'tops': -0.0005099999999999996,
#  'purpose': -0.0019900000000000013,
#  'jetpowered': -0.0002,
#  'madeleine': -0.00020000000000000004,
#  'scandals': 5.551115123125785e-21,
#  'roshomonlike': 0.00019,
#  'againthese': 0.0002,
#  'proposes': -0.0004,
#  'boggs': -0.0002,
#  'charges': -1.8041124150158802e-20,
#  'deduce': 0.00020000000000000004,
#  'lamp': 0.00020000000000000004,
#  'stature': -0.0004000000000000001,
#  'ferociously': 0.0002,
#  'yuks': 1.110223024625157e-20,
#  'mismatched': -0.00019999999999999998,
#  'bitter': 0.0011999999999999988,
#  'aww': 0.0002,
#  'italoamerican': 3e-05,
#  'wadingpool': -0.0002,
#  'marry': 0.00019999999999999998,
#  'vacationers': -0.00020000000000000004,
#  'landscaper': -0.00020000000000000004,
#  'egodriven': -0.00020000000000000004,
#  'around': -0.0035300000000000114,
#  '_dragonheart_': 0.00020000000000000004,
#  'flubberenhanced': -0.00019999999999999998,
#  'swastikas': 0.0002,
#  'gabby': -0.00020000000000000004,
#  'sinatra': 0.00019999999999999998,
#  'failing': -0.0005999999999999995,
#  'bo': -0.00020000000000000004,
#  'crossbows': -0.00019999999999999998,
#  'bursts': -0.00042999999999999994,
#  'romano': 0.00020000000000000004,
#  'retro': 0.00020000000000000004,
#  'robby': 0.0011999999999999995,
#  "ancestor's": -0.00020000000000000004,
#  'spatial': 0.0003999999999999999,
#  'physicist': -0.00019999999999999996,
#  'oneness': -0.00019999999999999998,
#  'requisite': -9.714451465470124e-21,
#  'driven': -0.00039999999999999986,
#  'resolutions': 0.00019999999999999993,
#  'unreal': 0.00037,
#  'sync': 0.00039999999999999996,
#  'yards': 3.999999999999999e-05,
#  'tvshow': 0.0002,
#  'masse': 0.0005799999999999997,
#  'unimaginative': -0.0008000000000000001,
#  'coproducing': 0.00018999999999999998,
#  'duval': -0.0008000000000000001,
#  'exaggerated': -0.0002,
#  'twister': 0.0004000000000000001,
#  'stood': -0.0003999999999999999,
#  'kilometres': 0.00018999999999999998,
#  'nsa': 2.7755575615628926e-21,
#  'tackles': 0.0005899999999999999,
#  'ripped': -0.0005699999999999999,
#  'rapes': 0.0004,
#  'spunk': -0.00019999999999999996,
#  'lite': -0.0002,
#  'aroway': 0.00020000000000000004,
#  'smooth': 0.00039999999999999996,
#  'derived': -0.00019999999999999996,
#  "helli'll": -0.0002,
#  'pure': 0.0011499999999999993,
#  'forgiveness': 0.00020000000000000004,
#  'spungen': -0.00019999999999999996,
#  'profoundly': -0.00040000000000000013,
#  'derelict': -0.0002,
#  'kersey': -0.0015999999999999999,
#  'wonderment': 0.0002,
#  'deflect': -0.0002,
#  "braddock's": 0.0002,
#  'sweetest': 0.0002,
#  'shared': 0.0004,
#  'sandler': 0.0032000000000000023,
#  'foulmouthed': -5.828670879282075e-20,
#  'stunned': -0.00019999999999999996,
#  'peer': -3.469446951953616e-20,
#  'disgusting': -0.00019999999999999993,
#  'immeasurably': 9.999999999999997e-06,
#  'insideout': 0.00020000000000000004,
#  'submarines': -0.00019999999999999996,
#  'remakescumbastardizations': -0.00020000000000000004,
#  'conducive': 0.0002,
#  'album': 0.0002000000000000001,
#  'woods': -0.0001999999999999999,
#  "felix's": 0.001,
#  'whimsical': -0.0004,
#  'depending': -0.00034999999999999994,
#  'sorvino': -0.00114,
#  'pad': 0.00020000000000000006,
#  'sheridan': 0.00019999999999999998,
#  'thoughts': -0.0014099999999999996,
#  'reporter': -0.00019999999999999993,
#  'suprising': 0.00019999999999999998,
#  'showtime': -0.0002,
#  'crotch': -0.0002,
#  'consensus': 0.00019999999999999998,
#  'publicparticularly': -0.00019999999999999998,
#  'vining': -0.0002,
#  'eulogy': -0.0004,
#  'sketchy': -0.0002,
#  'annoys': -0.0004,
#  'owing': -0.00019999999999999996,
#  '50minute': -0.00020000000000000004,
#  'sitch': 0.0004,
#  'parable': 0.00039999999999999996,
#  '2470': 0.00019999999999999998,
#  'popular': 0.0002600000000000003,
#  'disciple': 0.00038999999999999994,
#  'severity': 0.00019999999999999998,
#  'evoke': 0.0004,
#  'stomachturning': 0.00020000000000000004,
#  'taint': -0.00019000000000000004,
#  'laught': -0.0002,
#  'overzealous': -0.0002,
#  'woodbine': -0.0002,
#  "`whateverhappenedto'": -0.00019999999999999998,
#  'geez': -0.00039,
#  'slugfest': -0.0002,
#  'weeks': 0.0003999999999999999,
#  'poorlymotivated': -0.0002,
#  'presenter': -0.00019999999999999998,
#  'truer': -0.0002,
#  'lens': 0.00020000000000000004,
#  'refer': -9.999999999999997e-06,
#  'sleezebag': 0.00020000000000000004,
#  'bernhard': 0.0004,
#  'texas': -0.0009999999999999998,
#  'abbots': 0.0002,
#  'extracurricular': 0.0004000000000000001,
#  'linger': 0.00039999999999999996,
#  'bleach': -0.00020000000000000004,
#  'cultist': 0.00019999999999999998,
#  "mchale's": -0.0003999999999999999,
#  'galeweathers': -0.00019999999999999998,
#  'camp': -0.0004,
#  'argued': 0.00039999999999999996,
#  'yagher': 0.0002,
#  'supremely': 0.00019999999999999998,
#  'bisexual': 0.00020000000000000004,
#  "`total'": -0.0002,
#  'puts': -0.00023000000000000003,
#  "louise'": 0.00019999999999999998,
#  'amusement': 2.7755575615628926e-21,
#  'lukanic': -0.00019999999999999996,
#  'teenage': -0.0026300000000000056,
#  'whites': 0.0002,
#  'dramatic': -9.99999999999995e-06,
#  'assassin': 0.00019000000000000006,
#  'lerner': 0.00019999999999999998,
#  'investing': 0.00020000000000000004,
#  'dt': -2.999999999999998e-05,
#  'quintessential': 9.999999999999996e-06,
#  'channing': -0.00019999999999999998,
#  'rendezvous': 0.00020000000000000004,
#  'jealous': 0.00020000000000000004,
#  'chuckleoutloud': -0.00019999999999999996,
#  'steinberg': 0.00019999999999999998,
#  'berkshire': -0.00019999999999999993,
#  'looking': 0.00010999999999999984,
#  'nightclub': 0.0004399999999999998,
#  'honesty': 0.0004699999999999997,
#  'underrated': 0.0008,
#  'involving': -0.00181,
#  'disown': 0.0002,
#  'orsen': 0.00019999999999999998,
#  "timer'": -0.00019999999999999998,
#  'boils': -0.0002,
#  'compliment': -0.0005999999999999997,
#  'comeback': 0.0003900000000000001,
#  'killings': 0.00020000000000000004,
#  'aiello': 0.0004000000000000001,
#  'elie': 0.0002,
#  'receive': 0.00062,
#  'garrett': -0.0008,
#  'sobbing': 0.00041000000000000005,
#  'slam': -0.0006,
#  'sequenceflashback': -0.0002,
#  'shiavelli': 0.0002,
#  'predetermine': 0.00020000000000000004,
#  'bitterly': -0.00020000000000000004,
#  'squander': -0.00019999999999999998,
#  'nazareth': 0.00020000000000000004,
#  'skater': -0.0006000000000000001,
#  'rogue': 0.0002,
#  'tightfitting': -0.00019999999999999996,
#  'reference': 1.0000000000000014e-05,
#  'winona': 0.0004,
#  'truckers': -0.0002,
#  'deserving': -0.0005999999999999995,
#  'airwaves': 0.00019999999999999998,
#  'cheung': -0.00019999999999999998,
#  'postulate': 0.00019999999999999996,
#  'hound': 0.00019999999999999998,
#  'hypothetical': -0.0004,
#  'insouciance': -0.0003999999999999999,
#  'plimpton': -0.00020000000000000004,
#  'production': -0.0025800000000000068,
#  'schumacher': -0.0008000000000000001,
#  'tidal': -0.0006,
#  'messageid': -0.00017,
#  'funhouse': -0.00039999999999999996,
#  "cohn's": -0.0002,
#  'adventures': 0.001199999999999999,
#  'laterintheyear': -0.00020000000000000004,
#  'pudding': -0.0002,
#  'reece': 0.00020000000000000004,
#  'aztec': -0.00020000000000000004,
#  'lumber': 0.00019,
#  'asexual': 0.00018999999999999996,
#  'deanna': -0.0004000000000000001,
#  'proceed': -0.00020000000000000004,
#  'request': 1.0000000000000006e-05,
#  'supply': 0.00020000000000000004,
#  'diggs': 0.0004,
#  'leon': -0.002,
#  'injured': -0.0004,
#  'thirdperson': 0.00019999999999999998,
#  'kristin': 1.3877787807814463e-21,
#  'books': 0.00011999999999999999,
#  'sequences': -0.0038100000000000148,
#  'doublezero': -0.00019999999999999998,
#  'trains': 1.110223024625157e-20,
#  'surreal': -0.0009899999999999991,
#  'oracle': 0.0002,
#  'compares': 0.00039000000000000005,
#  'embarass': 0.00019999999999999996,
#  '98': -5.551115123125785e-21,
#  'earned': 0.0004899999999999998,
#  'tries': -0.003350000000000003,
#  'slade': 0.00020000000000000006,
#  'casually': -1.110223024625157e-20,
#  'montana': 0.0017999999999999997,
#  'soundwave': 0.00019999999999999998,
#  'usurp': 0.0002,
#  'unoriginal': -0.0008,
#  'thirtysomething': 0.0002,
#  'swing': -0.0005999999999999996,
#  'date': 0.0023200000000000004,
#  'regimes': 0.00039999999999999996,
#  'swishing': 0.0002,
#  'greatness': 0.00021,
#  'talking': -0.002560000000000008,
#  'cosmonaut': 0.00017999999999999998,
#  'xv': 0.0002,
#  'betrayal': 0.0013799999999999982,
#  'fantasy': 0.00022999999999999982,
#  'botched': 0.00019999999999999993,
#  'showgirls': -0.0005699999999999998,
#  'diminutive': 0.00039999999999999996,
#  'seenlittle': -0.0002,
#  'greystoke': -0.00019999999999999998,
#  'raining': -0.00019999999999999993,
#  'alters': 0.0002,
#  'ludicrously': -0.0002,
#  'leoni': -0.0006,
#  'genzel': -0.00020000000000000004,
#  'ham': -0.00019999999999999996,
#  'hats': 0.00039,
#  'pal': 2.636779683484748e-20,
#  'mating': -0.00039999999999999996,
#  'generated': 0.001,
#  'girlpower': 0.0002,
#  'lovely': 0.0006900000000000002,
#  'curious': 0.0,
#  'guide': -0.00021000000000000014,
#  'revengeand': -0.0002,
#  '2099': -0.0002,
#  'crime': -0.00013999999999999988,
#  "davis's": 0.0002,
#  "elizabeth's": -0.0002,
#  'exquisitely': 0.0002,
#  'hulot': 0.0022,
#  'costuming': 0.00020000000000000004,
#  'enthusiasts': 0.0002,
#  'mitchell': 0.0015999999999999992,
#  'refreshing': 0.0024400000000000064,
#  'export': -0.00019999999999999998,
#  'cams': 0.0012000000000000001,
#  'invitation': -0.00019999999999999996,
#  'schmaltzy': 0.00020000000000000004,
#  'paths': -0.00036999999999999994,
#  'finishing': 5.999999999999996e-05,
#  'guns': -0.0002800000000000001,
#  'pugilistic': 0.0002,
#  'em': -0.0004,
#  'werewolves': 0.00020000000000000004,
#  'lady': 0.0009799999999999998,
#  'oprah': 0.0007600000000000002,
#  "twohy's": 0.0002,
#  'fireballs': -9.714451465470124e-21,
#  'comment': 0.00022999999999999995,
#  'ages': 0.0008300000000000001,
#  'putit': 9.999999999999997e-06,
#  'tragically': -0.0005999999999999997,
#  'trafficking': -0.00019999999999999998,
#  'livened': -0.00020000000000000004,
#  'jimmie': 0.0003899999999999999,
#  'reallythey': 0.0002,
#  'prominently': -0.00020000000000000004,
#  'contextual': -0.0002,
#  'mara': 0.00019999999999999993,
#  'waterfall': -0.00039999999999999996,
#  'evidence': -0.0017999999999999993,
#  'guarantees': 0.0002,
#  'micelli': -0.0004,
#  'martinisand': -0.00019999999999999996,
#  'miller': 0.0006199999999999999,
#  'preference': 0.0002,
#  'species': -0.001739999999999999,
#  'wristwatch': -0.0004000000000000001,
#  'declared': 0.0005999999999999997,
#  'locker': 0.0002,
#  "'round": 0.0002,
#  'laugher': 0.00020000000000000004,
#  'gamely': -0.00020000000000000004,
#  'consciousness': 0.0006,
#  "shark's": 0.0002,
#  'christof': 0.0014000000000000004,
#  'horrified': -4.7184478546569174e-20,
#  'hammerhead': -0.00019999999999999998,
#  'thusly': -0.00019999999999999998,
#  "`elvis'": -0.0002,
#  'kissyface': -0.00020000000000000004,
#  'projectors': 0.0004,
#  'conglomerate': 0.0004,
#  'speeding': -0.00020000000000000006,
#  'rapist': -0.00020000000000000004,
#  'mint': -0.00019999999999999998,
#  'pictureperfect': 0.00019999999999999998,
#  'ensue': 0.00019999999999999998,
#  'chompers': -0.0004000000000000001,
#  'facility': 1.3877787807814463e-20,
#  'troubled': 0.0032000000000000093,
#  'vito': 3e-05,
#  "mob's": 0.0005999999999999998,
#  'biology': 0.00019999999999999998,
#  'futuristic': 0.0007999999999999999,
#  'radiates': -0.0002,
#  'crazed': 9.999999999999992e-06,
#  '_poltergeist_': 0.00020000000000000004,
#  'lightly': -0.0001999999999999999,
#  'kinfolk': -0.00019999999999999996,
#  'cinemax': -0.00039999999999999996,
#  'advertising': -0.00020000000000000006,
#  'arkfull': 9.999999999999997e-06,
#  'delaney': -0.00059,
#  'northeast': 0.0002,
#  'hopelessly': -0.0003900000000000001,
#  'davidson': 0.0002,
#  'idealistic': 0.0002,
#  'admires': 0.00019999999999999998,
#  "oteri's": -0.00019999999999999998,
#  "fear'": 0.0002,
#  'occuring': 0.0002,
#  'flippant': -0.00020000000000000004,
#  'blasts': -1.3877787807814463e-20,
#  '_little': 0.00020000000000000004,
#  'acception': 0.0002,
#  'razzmatazz': -0.0002,
#  "70's": 0.0005999999999999996,
#  'fortunate': 0.0004399999999999998,
#  'bumping': -0.0002,
#  'fusing': 0.00019999999999999998,
#  'memories': 0.0009300000000000003,
#  "opus'": 0.00039999999999999996,
#  'coraghessan': 0.00019999999999999998,
#  'trade': 0.0003699999999999997,
#  'dustin': 0.00020000000000000006,
#  'romance': -0.000549999999999999,
#  'yapping': 0.00019999999999999996,
#  'spader': -6.800116025829087e-20,
#  'padua': 0.00020000000000000004,
#  'lake': 0.0015999999999999973,
#  'loews': -0.00019999999999999998,
#  'overview': 0.00019999999999999998,
#  'reassures': 0.0002,
#  'smoothly': 0.00020000000000000004,
#  'sleeps': 0.0002,
#  'rapidly': -0.00020000000000000015,
#  'shallowness': -0.00039999999999999996,
#  'intentions': 1.0000000000000057e-05,
#  'juice': -0.0004000000000000001,
#  'weber': 0.00037999999999999997,
#  'crisply': -0.00020000000000000004,
#  'exboyfriend': -0.0004000000000000001,
#  'succeeds': 0.001049999999999999,
#  'privates': 0.00019999999999999998,
#  'quigon': 0.00076,
#  'chivalry': 0.0004000000000000001,
#  'wantor': -0.00019999999999999998,
#  'constable': -0.00019999999999999996,
#  'breillat': -0.001,
#  'mccamus': 0.00019999999999999998,
#  'shifts': 0.0010399999999999995,
#  'teaming': 0.00039999999999999996,
#  'specifics': -0.0004,
#  'fell': -0.00039999999999999996,
#  'warnings': -0.00019999999999999996,
#  'rampage': -0.0004,
#  'distracting': 0.0015899999999999957,
#  'wrongdoing': 0.0004000000000000001,
#  'root': 0.00021999999999999998,
#  'pulls': 0.0011599999999999983,
#  'oblivion': -0.00020000000000000004,
#  'elizondo': -0.00020000000000000004,
#  'zeke': 0.00020000000000000004,
#  'unlike': 0.004150000000000015,
#  'rigmarole': 0.00020000000000000004,
#  'confide': 0.00019999999999999998,
#  'watered': -0.00019999999999999993,
#  'powell': -0.0024000000000000002,
#  'quaid': -0.0009599999999999995,
#  'boasted': 0.00039999999999999996,
#  'glazed': 0.0002,
#  'ithe': 0.00019999999999999996,
#  'passengers': -0.0011999999999999992,
#  'diplomatic': 0.0002,
#  'disintegrated': 0.00020000000000000004,
#  'luck': -0.0022000000000000036,
#  'reacting': 0.00019999999999999996,
#  "lange's": -0.0004,
#  'disturbs': 0.00019999999999999996,
#  'iranian': 0.0002,
#  'bakkers': -0.0002,
#  'excitement': -0.00057,
#  'optimistic': 4.163336342344339e-21,
#  'motorcyclists': -0.0002,
#  'indignities': 0.00020000000000000004,
#  'advanced': -0.00037,
#  'scripted': 9.999999999999967e-06,
#  'neighborhood': -0.00021000000000000006,
#  'gettogethers': 0.0002,
#  'fruits': 0.0002,
#  'la': -0.00011000000000000003,
#  'fullest': 0.00039000000000000005,
#  'carrier': -9.999999999999986e-06,
#  'lifesaver': 0.00020000000000000004,
#  "paradise'": -0.00019999999999999996,
#  'blush': 0.00019,
#  'coproduction': -0.0002,
#  'makeover': -2.0816681711721695e-20,
#  '139': 0.00019999999999999998,
#  'discovers': -0.0004299999999999994,
#  'drinking': -0.0003999999999999999,
#  'moreau': -0.0002,
#  'tossing': 0.00041,
#  'masculinity': 0.0006000000000000002,
#  'pistol': -0.00020000000000000004,
#  'granger': -0.00019999999999999998,
#  '`ppppplease': 0.0002,
#  "priestley's": -0.00020000000000000004,
#  'valentine': -0.0007999999999999999,
#  'damper': 0.0002,
#  'painting': 0.001659999999999998,
#  "dafoe's": -0.0007999999999999999,
#  'sustain': -0.0005999999999999997,
#  'novelist': 0.0002,
#  'eerie': 0.00039999999999999975,
#  'towel': -0.00019999999999999996,
#  'narrated': 0.00020000000000000004,
#  'cleavagebusting': -0.0005999999999999998,
#  'chant': 0.00018999999999999998,
#  'termination': 0.0004000000000000001,
#  'jehan': 0.0004,
#  'distracts': -0.0003900000000000001,
#  'copturnedprivate': -0.00020000000000000004,
#  'pooch': -0.00019999999999999998,
#  'benito': 0.0003999999999999999,
#  'envelop': -0.0002,
#  'toys': -0.0005999999999999997,
#  'inherited': -1.3877787807814463e-21,
#  ...}

# %%
def percent_error(w, X, y):
    '''
    w is the sparse weight vector
    X is the vector needed to be classified
    y is the true label
    --------------------------
    error is the percent of the wrong classifiation
    '''
    count = 0
    N = len(X)
    
    for i in range(N):
        yy = dotProduct(w, X[i])
        #print(yy)
        if yy > 0:
            yy = 1
        else:
            yy = -1
        #print(yy)  
        if yy !=y[i]:
            count +=1
    #print(count)
    error = count/N
    return error

# %%
percent_error(w, X_valid, y_valid)
# Out:
# 0.16

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
errors = []
for i in range(-5,2):
    Lambda = 10**i;
    w = pegasos_svm_change(X_train, y_train, Lambda=Lambda, num_iter=20)
    errors.append(percent_error(w, X_valid, y_valid))
    print(Lambda, percent_error(w, X_valid, y_valid))

plt.plot(range(-5,2), errors)
plt.xlabel("lambda")
plt.ylabel("error")
plt.savefig('/Users/twff/Downloads/machine_learning/hw/hw3-sentiment/img66')
# Out:
# The time of the 1 epoch is 0.2563915619975887
# The time of the 2 epoch is 0.2045907179999631
# The time of the 3 epoch is 0.24685437401058152
# The time of the 4 epoch is 0.3370509530068375
# The time of the 5 epoch is 0.36352917000476737
# The time of the 6 epoch is 0.21880547401087824
# The time of the 7 epoch is 0.19882428301207256
# The time of the 8 epoch is 0.19682278600521386
# The time of the 9 epoch is 0.18736131599871442
# The time of the 10 epoch is 0.20991503199911676
# The time of the 11 epoch is 0.18067737300589215
# The time of the 12 epoch is 0.1993742549966555
# The time of the 13 epoch is 0.19116264399781357
# The time of the 14 epoch is 0.19118259599781595
# The time of the 15 epoch is 0.18240006500855088
# The time of the 16 epoch is 0.19952478900086135
# The time of the 17 epoch is 0.19036412899731658
# The time of the 18 epoch is 0.23259674599103164
# The time of the 19 epoch is 0.2917004140035715
# The time of the 20 epoch is 0.24670026199601125
# 3.70074341541715e-21
# 1e-05 0.154
# The time of the 1 epoch is 0.3100519029976567
# The time of the 2 epoch is 0.19803138900897466
# The time of the 3 epoch is 0.23053302700282075
# The time of the 4 epoch is 0.33435459800239187
# The time of the 5 epoch is 0.21488664399657864
# The time of the 6 epoch is 0.2040428280015476
# The time of the 7 epoch is 0.19764633500017226
# The time of the 8 epoch is 0.23875697499897797
# The time of the 9 epoch is 0.2064945199963404
# The time of the 10 epoch is 0.22282262099906802
# The time of the 11 epoch is 0.21346898400224745
# The time of the 12 epoch is 0.21645675499166828
# The time of the 13 epoch is 0.22085364699887577
# The time of the 14 epoch is 0.23599377399659716
# The time of the 15 epoch is 0.2126176250021672
# The time of the 16 epoch is 0.2134905980055919
# The time of the 17 epoch is 0.2167180739925243
# The time of the 18 epoch is 0.20759148300567176
# The time of the 19 epoch is 0.3111926519923145
# The time of the 20 epoch is 0.3203673499956494
# 3.3333333333332996e-05
# 0.0001 0.176
# The time of the 1 epoch is 0.3071215219970327
# The time of the 2 epoch is 0.24448335300257895
# The time of the 3 epoch is 0.27929011499509215
# The time of the 4 epoch is 0.2347257879882818
# The time of the 5 epoch is 0.2656488310021814
# The time of the 6 epoch is 0.29752858499705326
# The time of the 7 epoch is 0.20155736900051124
# The time of the 8 epoch is 0.20533703699766193
# The time of the 9 epoch is 0.21644844800175633
# The time of the 10 epoch is 0.2310945359931793
# The time of the 11 epoch is 0.22742157500761095
# The time of the 12 epoch is 0.21888162099639885
# The time of the 13 epoch is 0.2272784170054365
# The time of the 14 epoch is 0.21428355100215413
# The time of the 15 epoch is 0.18602025001018774
# The time of the 16 epoch is 0.22891480800171848
# The time of the 17 epoch is 0.2193865440058289
# The time of the 18 epoch is 0.20084673500969075
# The time of the 19 epoch is 0.3027075449936092
# The time of the 20 epoch is 0.38931473399861716
# 3.333333333333299e-05
# 0.001 0.16
# The time of the 1 epoch is 0.40243673499207944
# The time of the 2 epoch is 0.24755215500772465
# The time of the 3 epoch is 0.21941967800376005
# The time of the 4 epoch is 0.2152492019959027
# The time of the 5 epoch is 0.20090876599715557
# The time of the 6 epoch is 0.2255116689921124
# The time of the 7 epoch is 0.21121255699836183
# The time of the 8 epoch is 0.3023086730099749
# The time of the 9 epoch is 0.22239794200868346
# The time of the 10 epoch is 0.26761443201394286
# The time of the 11 epoch is 0.2492214480007533
# The time of the 12 epoch is 0.2893402750050882
# The time of the 13 epoch is 0.24553217701031826
# The time of the 14 epoch is 0.21905689500272274
# The time of the 15 epoch is 0.2230564640049124
# The time of the 16 epoch is 0.20844915599445812
# The time of the 17 epoch is 0.20503446999646258
# The time of the 18 epoch is 0.1926188479992561
# The time of the 19 epoch is 0.19605042900366243
# The time of the 20 epoch is 0.22657992999302223
# 3.333333333333299e-05
# 0.01 0.182
# The time of the 1 epoch is 0.3544478099938715
# The time of the 2 epoch is 0.3637529060069937
# The time of the 3 epoch is 0.33931869101070333
# The time of the 4 epoch is 0.22964456499903463
# The time of the 5 epoch is 0.26450909599952865
# The time of the 6 epoch is 0.23359169000468682
# The time of the 7 epoch is 0.31789511800161563
# The time of the 8 epoch is 0.34296076200553216
# The time of the 9 epoch is 0.3075495619996218
# The time of the 10 epoch is 0.2812745580013143
# The time of the 11 epoch is 0.24822408899490256
# The time of the 12 epoch is 0.24049699598981533
# The time of the 13 epoch is 0.27689658499730285
# The time of the 14 epoch is 0.3135727929911809
# The time of the 15 epoch is 0.3622840400057612
# The time of the 16 epoch is 0.2981005350011401
# The time of the 17 epoch is 0.318967897008406
# The time of the 18 epoch is 0.2697803629998816
# The time of the 19 epoch is 0.31010873899504077
# The time of the 20 epoch is 0.2678239530068822
# 3.3333333333332996e-05
# 0.1 0.162
# The time of the 1 epoch is 0.4108738640061347
# The time of the 2 epoch is 0.3890581769956043
# The time of the 3 epoch is 0.32175357300729956
# The time of the 4 epoch is 0.44834824099962134
# The time of the 5 epoch is 0.4346938610106008
# The time of the 6 epoch is 0.46342306899896357
# The time of the 7 epoch is 0.480629081997904
# The time of the 8 epoch is 0.41147083599935286
# The time of the 9 epoch is 0.35842408999451436
# The time of the 10 epoch is 0.3959715599921765
# The time of the 11 epoch is 0.42320646900043357
# The time of the 12 epoch is 0.38810301400371827
# The time of the 13 epoch is 0.40807910899457056
# The time of the 14 epoch is 0.35055951699905563
# The time of the 15 epoch is 0.4235472410073271
# The time of the 16 epoch is 0.37075636399094947
# The time of the 17 epoch is 0.3251217020006152
# The time of the 18 epoch is 0.4363938009919366
# The time of the 19 epoch is 0.35208971399697475
# The time of the 20 epoch is 0.40556415800529066
# 3.3333333333332996e-05
# 1 0.158
# The time of the 1 epoch is 0.36920470300538
# The time of the 2 epoch is 0.3818755149986828
# The time of the 3 epoch is 0.541025461992831
# The time of the 4 epoch is 0.3856926239968743
# The time of the 5 epoch is 0.36283382200053893
# The time of the 6 epoch is 0.49487174999376293
# The time of the 7 epoch is 0.4396976300049573
# The time of the 8 epoch is 0.5232098540000152
# The time of the 9 epoch is 0.6003788609959884
# The time of the 10 epoch is 0.43041576200630516
# The time of the 11 epoch is 0.40823786999681033
# The time of the 12 epoch is 0.5696278980030911
# The time of the 13 epoch is 0.43809361700550653
# The time of the 14 epoch is 0.37991639599204063
# The time of the 15 epoch is 0.3548513179994188
# The time of the 16 epoch is 0.35469770499912556
# The time of the 17 epoch is 0.3684231549996184
# The time of the 18 epoch is 0.35496951000823174
# The time of the 19 epoch is 0.3433476689970121
# The time of the 20 epoch is 0.34106477300520055
# 3.333333333333299e-05
# 10 0.286

# %%
Lambda = np.linspace(0,2,20)
errors = []
for i in range(len(Lambda)):
    w = pegasos_svm_change(X_train, y_train, Lambda=Lambda[i], num_iter=20)
    errors.append(percent_error(w, X_valid, y_valid))
    print(Lambda[i], percent_error(w, X_valid, y_valid))

plt.plot(Lambda, errors)
plt.xlabel("lambda")
plt.ylabel("error")
plt.savefig('/Users/twff/Downloads/machine_learning/hw/hw3-sentiment/img66b')
# Out:
# /Users/twff/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:20: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/twff/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:21: RuntimeWarning: invalid value encountered in double_scalars
# The time of the 1 epoch is 0.01161651499569416
# The time of the 2 epoch is 0.010885889001656324
# The time of the 3 epoch is 0.011225303998799063
# The time of the 4 epoch is 0.012495692004449666
# The time of the 5 epoch is 0.014599881003960036
# The time of the 6 epoch is 0.01302927300275769
# The time of the 7 epoch is 0.012920773006044328
# The time of the 8 epoch is 0.011529498995514587
# The time of the 9 epoch is 0.011366797989467159
# The time of the 10 epoch is 0.010354676996939816
# The time of the 11 epoch is 0.010475862989551388
# The time of the 12 epoch is 0.009841477003647014
# The time of the 13 epoch is 0.010326190997147933
# The time of the 14 epoch is 0.010062817993457429
# The time of the 15 epoch is 0.013655479997396469
# The time of the 16 epoch is 0.010291717000654899
# The time of the 17 epoch is 0.009796814003493637
# The time of the 18 epoch is 0.009862601000349969
# The time of the 19 epoch is 0.009822378007811494
# The time of the 20 epoch is 0.009836106008151546
# nan
# 0.0 0.49
# The time of the 1 epoch is 0.3904003399948124
# The time of the 2 epoch is 0.3560554959985893
# The time of the 3 epoch is 0.35182763398915995
# The time of the 4 epoch is 0.41070086500258185
# The time of the 5 epoch is 0.43301074899500236
# The time of the 6 epoch is 0.5435646349942544
# The time of the 7 epoch is 0.3921212229906814
# The time of the 8 epoch is 0.35991221100266557
# The time of the 9 epoch is 0.38247566000791267
# The time of the 10 epoch is 0.3733351529954234
# The time of the 11 epoch is 0.36956434200692456
# The time of the 12 epoch is 0.38074537699867506
# The time of the 13 epoch is 0.3733627199981129
# The time of the 14 epoch is 0.3869360999960918
# The time of the 15 epoch is 0.38749641498725396
# The time of the 16 epoch is 0.36767169399536215
# The time of the 17 epoch is 0.38245734899828676
# The time of the 18 epoch is 0.3778386369958753
# The time of the 19 epoch is 0.39560836099553853
# The time of the 20 epoch is 0.37218380899867043
# 3.33333333333e-05
# 0.105263157895 0.15
# The time of the 1 epoch is 0.4305225149873877
# The time of the 2 epoch is 0.4228907549986616
# The time of the 3 epoch is 0.4164744270092342
# The time of the 4 epoch is 0.40986745299596805
# The time of the 5 epoch is 0.40175663800619077
# The time of the 6 epoch is 0.42819075999432243
# The time of the 7 epoch is 0.4226193880022038
# The time of the 8 epoch is 0.41852927800209727
# The time of the 9 epoch is 0.4137036350002745
# The time of the 10 epoch is 0.4404250750085339
# The time of the 11 epoch is 0.6616731349931797
# The time of the 12 epoch is 0.40159171499544755
# The time of the 13 epoch is 0.6224726889922749
# The time of the 14 epoch is 0.5423930670076516
# The time of the 15 epoch is 0.39167956401070114
# The time of the 16 epoch is 0.40768449699680787
# The time of the 17 epoch is 0.6360014810052235
# The time of the 18 epoch is 0.5214955100091174
# The time of the 19 epoch is 0.5012305950076552
# The time of the 20 epoch is 0.6272338520066114
# 3.33333333333e-05
# 0.210526315789 0.156
# The time of the 1 epoch is 0.4355762329942081
# The time of the 2 epoch is 0.48167827300494537
# The time of the 3 epoch is 0.42205636999278795
# The time of the 4 epoch is 0.449334089003969
# The time of the 5 epoch is 0.4391016559966374
# The time of the 6 epoch is 0.44743713100615423
# The time of the 7 epoch is 0.4381693629984511
# The time of the 8 epoch is 0.44928322499617934
# The time of the 9 epoch is 0.44875426701037213
# The time of the 10 epoch is 0.4364096899953438
# The time of the 11 epoch is 0.4535319239948876
# The time of the 12 epoch is 0.4575571140012471
# The time of the 13 epoch is 0.4372079400054645
# The time of the 14 epoch is 0.455683175008744
# The time of the 15 epoch is 0.4384796369995456
# The time of the 16 epoch is 0.44103291000647005
# The time of the 17 epoch is 0.4469243389903568
# The time of the 18 epoch is 0.4488414079969516
# The time of the 19 epoch is 0.44982610500301234
# The time of the 20 epoch is 0.5846489569958067
# 3.33333333333e-05
# 0.315789473684 0.156
# The time of the 1 epoch is 0.5793436149979243
# The time of the 2 epoch is 0.646112874004757
# The time of the 3 epoch is 0.4313652609998826
# The time of the 4 epoch is 0.42728456800978165
# The time of the 5 epoch is 0.4572743650060147
# The time of the 6 epoch is 0.43723678498645313
# The time of the 7 epoch is 0.45073241599311586
# The time of the 8 epoch is 0.43139637299464084
# The time of the 9 epoch is 0.43246440700022504
# The time of the 10 epoch is 0.4450899229996139
# The time of the 11 epoch is 0.4345211160107283
# The time of the 12 epoch is 0.4233587220078334
# The time of the 13 epoch is 0.4253421140019782
# The time of the 14 epoch is 0.446109593991423
# The time of the 15 epoch is 0.4202660150040174
# The time of the 16 epoch is 0.44644746999256313
# The time of the 17 epoch is 0.43133863899856806
# The time of the 18 epoch is 0.42856678999669384
# The time of the 19 epoch is 0.4741840310016414
# The time of the 20 epoch is 0.6115254390024347
# 3.33333333333e-05
# 0.421052631579 0.158
# The time of the 1 epoch is 0.6009204690053593
# The time of the 2 epoch is 0.4581002150080167
# The time of the 3 epoch is 0.4393044250027742
# The time of the 4 epoch is 0.455038002008223
# The time of the 5 epoch is 0.4388819970045006
# The time of the 6 epoch is 0.4508620440028608
# The time of the 7 epoch is 0.4873745590011822
# The time of the 8 epoch is 0.4531878880079603
# The time of the 9 epoch is 0.44422500299697276
# The time of the 10 epoch is 0.47080193398869596
# The time of the 11 epoch is 0.5002605640038382
# The time of the 12 epoch is 0.4775275450083427
# The time of the 13 epoch is 0.47300626800279133
# The time of the 14 epoch is 0.4678904250031337
# The time of the 15 epoch is 0.4566079470096156
# The time of the 16 epoch is 0.47788401899742894
# The time of the 17 epoch is 0.47089761999086477
# The time of the 18 epoch is 0.6506131119967904
# The time of the 19 epoch is 0.5947944540093886
# The time of the 20 epoch is 0.4954616699978942
# 3.33333333333e-05
# 0.526315789474 0.156
# The time of the 1 epoch is 0.5485824600036722
# The time of the 2 epoch is 0.6429164630098967
# The time of the 3 epoch is 0.6680217020038981
# The time of the 4 epoch is 0.6840323590004118
# The time of the 5 epoch is 0.5874531240115175
# The time of the 6 epoch is 0.4735661160084419
# The time of the 7 epoch is 0.5649088759964798
# The time of the 8 epoch is 0.5767282669985434
# The time of the 9 epoch is 0.5610666509892326
# The time of the 10 epoch is 0.5951023630041163
# The time of the 11 epoch is 0.7126828100008424
# The time of the 12 epoch is 0.6978307159879478
# The time of the 13 epoch is 0.5500394539994886
# The time of the 14 epoch is 0.512048616001266
# The time of the 15 epoch is 0.46991099999286234
# The time of the 16 epoch is 0.4745515289978357
# The time of the 17 epoch is 0.7933696560066892
# The time of the 18 epoch is 0.6985749799932819
# The time of the 19 epoch is 0.6330558039917378
# The time of the 20 epoch is 0.7107689899858087
# 3.33333333333e-05
# 0.631578947368 0.152
# The time of the 1 epoch is 0.5301572339958511
# The time of the 2 epoch is 0.6972602140012896
# The time of the 3 epoch is 0.6987141919962596
# The time of the 4 epoch is 0.556264105005539
# The time of the 5 epoch is 0.5674331310001435
# The time of the 6 epoch is 0.6680699230055325
# The time of the 7 epoch is 0.5206393840053352
# The time of the 8 epoch is 0.49944973799574655
# The time of the 9 epoch is 0.7387783080048393
# The time of the 10 epoch is 0.6567841950018192
# The time of the 11 epoch is 0.688750297005754
# The time of the 12 epoch is 0.7237597539933631
# The time of the 13 epoch is 0.547098045994062
# The time of the 14 epoch is 0.6761613560083788
# The time of the 15 epoch is 0.6026662150106858
# The time of the 16 epoch is 0.45789087598677725
# The time of the 17 epoch is 0.45545572899573017
# The time of the 18 epoch is 0.46578651999880094
# The time of the 19 epoch is 0.4652580750116613
# The time of the 20 epoch is 0.4429803759994684
# 3.33333333333e-05
# 0.736842105263 0.148
# The time of the 1 epoch is 0.47035012900596485
# The time of the 2 epoch is 0.4687197840103181
# The time of the 3 epoch is 0.4602519729960477
# The time of the 4 epoch is 0.47284128599858377
# The time of the 5 epoch is 0.5061403650033753
# The time of the 6 epoch is 0.5252304349996848
# The time of the 7 epoch is 0.4651106119999895
# The time of the 8 epoch is 0.5028754309896613
# The time of the 9 epoch is 0.48639142999309115
# The time of the 10 epoch is 0.4743599049979821
# The time of the 11 epoch is 0.4673201039986452
# The time of the 12 epoch is 0.46018993500911165
# The time of the 13 epoch is 0.47851652900862973
# The time of the 14 epoch is 0.45953408800414763
# The time of the 15 epoch is 0.4887334030063357
# The time of the 16 epoch is 0.485643196007004
# The time of the 17 epoch is 0.46115865900355857
# The time of the 18 epoch is 0.46383671600779053
# The time of the 19 epoch is 0.4787086919968715
# The time of the 20 epoch is 0.4627657130040461
# 3.33333333333e-05
# 0.842105263158 0.152
# The time of the 1 epoch is 0.46519828200689517
# The time of the 2 epoch is 0.47777778599993326
# The time of the 3 epoch is 0.46155735399224795
# The time of the 4 epoch is 0.47048531399923377
# The time of the 5 epoch is 0.47137202600424644
# The time of the 6 epoch is 0.4887537299946416
# The time of the 7 epoch is 0.47859099401102867
# The time of the 8 epoch is 0.4694250419997843
# The time of the 9 epoch is 0.4661733200046001
# The time of the 10 epoch is 0.48189732199534774
# The time of the 11 epoch is 0.4628261079924414
# The time of the 12 epoch is 0.48251674300991
# The time of the 13 epoch is 0.47565273800864816
# The time of the 14 epoch is 0.4910731069976464
# The time of the 15 epoch is 0.4699488320038654
# The time of the 16 epoch is 0.49155964198871516
# The time of the 17 epoch is 0.46201728101004846
# The time of the 18 epoch is 0.4786811889935052
# The time of the 19 epoch is 0.4668272109993268
# The time of the 20 epoch is 0.4874844949954422
# 3.33333333333e-05
# 0.947368421053 0.154
# The time of the 1 epoch is 0.48717775000841357
# The time of the 2 epoch is 0.484561172008398
# The time of the 3 epoch is 0.4933074389991816
# The time of the 4 epoch is 0.49841448399820365
# The time of the 5 epoch is 0.47508524400473107
# The time of the 6 epoch is 0.4786170220031636
# The time of the 7 epoch is 0.4960562950000167
# The time of the 8 epoch is 0.5009287889988627
# The time of the 9 epoch is 0.47524836800585035
# The time of the 10 epoch is 0.48716022599546704
# The time of the 11 epoch is 0.4796131069888361
# The time of the 12 epoch is 0.4739781810058048
# The time of the 13 epoch is 0.4761654290050501
# The time of the 14 epoch is 0.47719826600223314
# The time of the 15 epoch is 0.4715939290035749
# The time of the 16 epoch is 0.47482324999873526
# The time of the 17 epoch is 0.49305844999616966
# The time of the 18 epoch is 0.48364055500132963
# The time of the 19 epoch is 0.48979496500396635
# The time of the 20 epoch is 0.47801057499600574
# 3.33333333333e-05
# 1.05263157895 0.158
# The time of the 1 epoch is 0.48067213500326034
# The time of the 2 epoch is 0.5026842969964491
# The time of the 3 epoch is 0.4875385310006095
# The time of the 4 epoch is 0.501223518003826
# The time of the 5 epoch is 0.478257847003988
# The time of the 6 epoch is 0.4892911159986397
# The time of the 7 epoch is 0.4773443320009392
# The time of the 8 epoch is 0.5030385670106625
# The time of the 9 epoch is 0.4846961309958715
# The time of the 10 epoch is 0.49135998501151334
# The time of the 11 epoch is 0.47242857799574267
# The time of the 12 epoch is 0.49029029499797616
# The time of the 13 epoch is 0.4810522429906996
# The time of the 14 epoch is 0.48486138599400874
# The time of the 15 epoch is 0.4981654500006698
# The time of the 16 epoch is 0.4882541919942014
# The time of the 17 epoch is 0.482007694998174
# The time of the 18 epoch is 0.47740244498709217
# The time of the 19 epoch is 0.49776843600557186
# The time of the 20 epoch is 0.47052534099202603
# 3.33333333333e-05
# 1.15789473684 0.164
# The time of the 1 epoch is 0.48719607800012454
# The time of the 2 epoch is 0.4839818920008838
# The time of the 3 epoch is 0.48125278200313915
# The time of the 4 epoch is 0.49147341899515595
# The time of the 5 epoch is 0.47352085800957866
# The time of the 6 epoch is 0.4869126179983141
# The time of the 7 epoch is 0.4837798819935415
# The time of the 8 epoch is 0.4776792339980602
# The time of the 9 epoch is 0.4862052779935766
# The time of the 10 epoch is 0.4797512730001472
# The time of the 11 epoch is 0.48222141100268345
# The time of the 12 epoch is 0.4882378819893347
# The time of the 13 epoch is 0.4926245809911052
# The time of the 14 epoch is 0.4857739699946251
# The time of the 15 epoch is 0.5039034149958752
# The time of the 16 epoch is 0.4929848960018717
# The time of the 17 epoch is 0.5009241870138794
# The time of the 18 epoch is 0.5283673599915346
# The time of the 19 epoch is 0.530052288013394
# The time of the 20 epoch is 0.502369292997173
# 3.33333333333e-05
# 1.26315789474 0.168
# The time of the 1 epoch is 0.4841591709991917
# The time of the 2 epoch is 0.4873667689971626
# The time of the 3 epoch is 0.4864214210101636
# The time of the 4 epoch is 0.48526845600281376
# The time of the 5 epoch is 0.4859328390011797
# The time of the 6 epoch is 0.48626943401177414
# The time of the 7 epoch is 0.48370511399116367
# The time of the 8 epoch is 0.4996336609910941
# The time of the 9 epoch is 0.48327405100280885
# The time of the 10 epoch is 0.5057158429990523
# The time of the 11 epoch is 0.4884310780034866
# The time of the 12 epoch is 0.49157104299229104
# The time of the 13 epoch is 0.4969367199955741
# The time of the 14 epoch is 0.5100844800035702
# The time of the 15 epoch is 0.5109834259928903
# The time of the 16 epoch is 0.49179269700834993
# The time of the 17 epoch is 0.48440597399894614
# The time of the 18 epoch is 0.48251429198717233
# The time of the 19 epoch is 0.48728408000897616
# The time of the 20 epoch is 0.4933157729974482
# 3.33333333333e-05
# 1.36842105263 0.168
# The time of the 1 epoch is 0.4925574919907376
# The time of the 2 epoch is 0.49065907500335015
# The time of the 3 epoch is 0.5002447020087857
# The time of the 4 epoch is 0.49286599399056286
# The time of the 5 epoch is 0.4968878099898575
# The time of the 6 epoch is 0.49778593800147064
# The time of the 7 epoch is 0.48987227799079847
# The time of the 8 epoch is 0.4888765080104349
# The time of the 9 epoch is 0.4853938510059379
# The time of the 10 epoch is 0.49783098899933975
# The time of the 11 epoch is 0.5043947649974143
# The time of the 12 epoch is 0.4883402449922869
# The time of the 13 epoch is 0.48055796600237954
# The time of the 14 epoch is 0.4948040029994445
# The time of the 15 epoch is 0.4847670279996237
# The time of the 16 epoch is 0.5056267849868163
# The time of the 17 epoch is 0.4984534109971719
# The time of the 18 epoch is 0.5102710619976278
# The time of the 19 epoch is 0.4912136089988053
# The time of the 20 epoch is 0.4899256560020149
# 3.33333333333e-05
# 1.47368421053 0.166
# The time of the 1 epoch is 0.4792016579885967
# The time of the 2 epoch is 0.49196190301154274
# The time of the 3 epoch is 0.4906977460050257
# The time of the 4 epoch is 0.500707263010554
# The time of the 5 epoch is 0.48658276700007264
# The time of the 6 epoch is 0.5139220449927961
# The time of the 7 epoch is 0.49917880300199613
# The time of the 8 epoch is 0.5015554449928459
# The time of the 9 epoch is 0.4851454629970249
# The time of the 10 epoch is 0.4914186649984913
# The time of the 11 epoch is 0.4951337490056176
# The time of the 12 epoch is 0.49015985199366696
# The time of the 13 epoch is 0.49137685299501754
# The time of the 14 epoch is 0.5175406680064043
# The time of the 15 epoch is 0.49095829199359287
# The time of the 16 epoch is 0.49180695999530144
# The time of the 17 epoch is 0.4920236940088216
# The time of the 18 epoch is 0.4908653540041996
# The time of the 19 epoch is 0.49924955899768975
# The time of the 20 epoch is 0.48968909500399604
# 3.33333333333e-05
# 1.57894736842 0.166
# The time of the 1 epoch is 0.4838675869978033
# The time of the 2 epoch is 0.5033167539950227
# The time of the 3 epoch is 0.4877648129913723
# The time of the 4 epoch is 0.5101897950080456
# The time of the 5 epoch is 0.4867164150055032
# The time of the 6 epoch is 0.49786626899731345
# The time of the 7 epoch is 0.493001347000245
# The time of the 8 epoch is 0.5019151760061504
# The time of the 9 epoch is 0.4891601450071903
# The time of the 10 epoch is 0.49415882099128794
# The time of the 11 epoch is 0.48471527600486297
# The time of the 12 epoch is 0.49793579799006693
# The time of the 13 epoch is 0.49395394799648784
# The time of the 14 epoch is 0.5232382069953019
# The time of the 15 epoch is 0.4968609839997953
# The time of the 16 epoch is 0.5177865479927277
# The time of the 17 epoch is 0.5098294929921394
# The time of the 18 epoch is 0.5029440990037983
# The time of the 19 epoch is 0.4918302119913278
# The time of the 20 epoch is 0.5067896360123996
# 3.33333333333e-05
# 1.68421052632 0.168
# The time of the 1 epoch is 0.5039762300002621
# The time of the 2 epoch is 0.4952723610040266
# The time of the 3 epoch is 0.49402959999861196
# The time of the 4 epoch is 0.49699925498862285
# The time of the 5 epoch is 0.501366381009575
# The time of the 6 epoch is 0.4932018719991902
# The time of the 7 epoch is 0.5027304520044709
# The time of the 8 epoch is 0.49113927100552246
# The time of the 9 epoch is 0.5088397249928676
# The time of the 10 epoch is 0.5037155600002734
# The time of the 11 epoch is 0.5012542210024549
# The time of the 12 epoch is 0.4931874809990404
# The time of the 13 epoch is 0.5163796169945272
# The time of the 14 epoch is 0.5058293530019
# The time of the 15 epoch is 0.5142046730034053
# The time of the 16 epoch is 0.5185289879882475
# The time of the 17 epoch is 0.4976822229946265
# The time of the 18 epoch is 0.49004450799839105
# The time of the 19 epoch is 0.5005926020094194
# The time of the 20 epoch is 0.49801335200027097
# 3.70074341542e-21
# 1.78947368421 0.17
# The time of the 1 epoch is 0.5076678139885189
# The time of the 2 epoch is 0.5053309630020522
# The time of the 3 epoch is 0.5017089460015995
# The time of the 4 epoch is 0.4992804690118646
# The time of the 5 epoch is 0.5086986300011631
# The time of the 6 epoch is 0.49446851598622743
# The time of the 7 epoch is 0.4993258550093742
# The time of the 8 epoch is 0.5150762909906916
# The time of the 9 epoch is 0.5113867460022448
# The time of the 10 epoch is 0.49609661899739876
# The time of the 11 epoch is 0.5140822709945496
# The time of the 12 epoch is 0.4944374410115415
# The time of the 13 epoch is 0.5054857979994267
# The time of the 14 epoch is 0.5079663549986435
# The time of the 15 epoch is 0.5169651819887804
# The time of the 16 epoch is 0.5740813790034736
# The time of the 17 epoch is 0.5422855729993898
# The time of the 18 epoch is 0.5013922030047979
# The time of the 19 epoch is 0.49582452900358476
# The time of the 20 epoch is 0.4997703239932889
# 3.33333333333e-05
# 1.89473684211 0.172
# The time of the 1 epoch is 0.5088761420047376
# The time of the 2 epoch is 0.5067719700018642
# The time of the 3 epoch is 0.4944029219914228
# The time of the 4 epoch is 0.5153954120032722
# The time of the 5 epoch is 0.5124788390094182
# The time of the 6 epoch is 0.5060468159936136
# The time of the 7 epoch is 0.5015083990001585
# The time of the 8 epoch is 0.5282124640070833
# The time of the 9 epoch is 0.5068761449947488
# The time of the 10 epoch is 0.5002571350050857
# The time of the 11 epoch is 0.5183953730011126
# The time of the 12 epoch is 0.5180838429951109
# The time of the 13 epoch is 0.5086475510033779
# The time of the 14 epoch is 0.5124038039939478
# The time of the 15 epoch is 0.5231152960041072
# The time of the 16 epoch is 0.5074970980058424
# The time of the 17 epoch is 0.515346774001955
# The time of the 18 epoch is 0.5855917219887488
# The time of the 19 epoch is 0.5600633180001751
# The time of the 20 epoch is 0.6836538649949944
# 3.33333333333e-05
# 2.0 0.18

# %% [markdown]
# ###  lambda = 0.1

# %% [markdown]
# #### optional

# %%
def predict_score_group(w, X, y):
    '''
    w is the sparse weight vector
    X is the vector needed to be classified
    y is the true label
    --------------------------
    error is the percent of the wrong classifiation
    '''
    count = 0
    N = len(X)
    
    for i in range(N):
        yy = dotProduct(w, X[i])
        print(yy)  
        if yy !=y[i]:
            count +=1
    #print(count)
    error = count/N
    return error

# %%
predict_score_group(w, X_valid, y_valid)
# Out:
# 0.319666666667
# 0.4804
# -0.0463666666667
# 1.33396666667
# -0.572533333333
# 1.501
# 0.9381
# 1.2322
# 0.564033333333
# 1.38303333333
# -0.0170333333333
# -1.2499
# 0.114733333333
# -0.0452333333333
# 0.1995
# 0.424766666667
# 0.222133333333
# -0.665233333333
# -0.996033333333
# -0.838566666667
# 1.10163333333
# 0.176966666667
# 2.355
# 1.1395
# 0.2651
# 1.10936666667
# 1.05303333333
# 0.363133333333
# 0.0309
# 0.0677666666667
# 0.7649
# 3.20803333333
# 1.1169
# 0.842033333333
# -0.898133333333
# 3.10636666667
# 0.5501
# -0.8795
# 1.1847
# 1.52306666667
# -0.271933333333
# 0.146633333333
# 2.72906666667
# 0.9397
# 0.2953
# -0.4569
# -0.2904
# 2.6225
# 0.433266666667
# -0.2594
# -0.598433333333
# 1.09803333333
# 0.1304
# -1.0084
# 0.567566666667
# -1.5991
# -0.0867333333333
# -0.312733333333
# 0.0541666666667
# -2.19463333333
# -1.65956666667
# 0.0424
# -0.136366666667
# -1.7789
# 1.16983333333
# 0.771533333333
# -0.5488
# 1.56483333333
# -1.3277
# 2.29303333333
# -0.505833333333
# 1.49866666667
# 0.0478333333333
# 0.8229
# 0.1982
# 0.909333333333
# 0.997333333333
# -1.23723333333
# -0.0882333333333
# -0.935666666667
# -1.61416666667
# 1.61806666667
# 0.504366666667
# -2.40526666667
# 1.628
# -0.173666666667
# -1.10113333333
# 0.935
# -0.655633333333
# -0.0149
# 0.2415
# 1.0083
# 0.8387
# -0.3089
# 1.11676666667
# 0.3319
# 0.699766666667
# -0.395833333333
# -1.0641
# 1.00546666667
# 0.408
# 0.280533333333
# -0.432533333333
# -0.344433333333
# -0.0945666666667
# -0.7063
# 0.399766666667
# -1.4338
# 1.01853333333
# 2.43966666667
# 1.08446666667
# -1.7297
# 0.349866666667
# -1.1637
# 1.43846666667
# 0.0185666666667
# 1.07056666667
# -1.08706666667
# -0.127866666667
# -0.174766666667
# -1.44453333333
# 0.310233333333
# 1.39113333333
# 0.7748
# 0.2239
# 0.528533333333
# -0.366533333333
# -0.197833333333
# 0.6815
# -0.214166666667
# -2.4828
# -1.00126666667
# -0.731033333333
# 2.13003333333
# -0.0340333333333
# -0.207433333333
# 0.0284333333333
# -0.7347
# -0.399
# 0.499966666667
# 0.670633333333
# -0.107433333333
# 0.6036
# -0.1175
# -1.16463333333
# -0.393133333333
# -0.200933333333
# 0.668
# -1.09776666667
# 0.390733333333
# 1.6032
# -0.230366666667
# -0.3377
# -0.0406
# 0.1315
# -0.160733333333
# -0.4066
# -0.169233333333
# 0.2955
# 0.554533333333
# 1.14556666667
# 0.912133333333
# -0.3992
# 0.746
# -1.3682
# 1.14443333333
# 0.2503
# -0.9138
# 0.671633333333
# 0.0587
# 0.757633333333
# -0.1372
# 0.0611333333333
# 1.01196666667
# 0.141533333333
# -0.545
# -0.4556
# 0.796433333333
# -0.1209
# -0.346966666667
# -1.0527
# 0.0509333333333
# -0.132933333333
# -0.6906
# 0.596533333333
# 0.970933333333
# 0.940333333333
# -1.3512
# 0.643966666667
# -1.7536
# 0.771666666667
# 0.502566666667
# -0.752033333333
# -0.177833333333
# 0.544033333333
# 0.113033333333
# -1.75286666667
# 0.5567
# -1.09446666667
# -0.5867
# 1.51236666667
# 0.0540333333333
# -0.161433333333
# 0.167266666667
# -0.4027
# -0.385066666667
# 1.0114
# -0.937766666667
# 0.9032
# 2.91916666667
# 1.05116666667
# 0.5109
# 1.1904
# -0.836
# 1.26026666667
# 0.162166666667
# -0.5372
# 2.0005
# 0.529233333333
# 0.776033333333
# -0.0152
# -0.7505
# -1.0074
# 0.541133333333
# -0.5825
# -0.264066666667
# -0.327266666667
# 0.0546666666667
# -1.8859
# 0.0619
# -1.10973333333
# -0.243833333333
# 0.7219
# -0.641433333333
# -0.528833333333
# -0.517566666667
# -0.669533333333
# 0.0593333333333
# -0.587266666667
# -0.152766666667
# 0.8451
# -0.687266666667
# -0.532666666667
# 1.04283333333
# -1.31566666667
# 1.1098
# 1.22203333333
# -0.164366666667
# 2.7642
# 0.429266666667
# 0.6515
# 0.0834
# -2.4298
# 1.0691
# -0.577233333333
# 0.0642333333333
# -0.736133333333
# 0.6602
# -0.819066666667
# 0.3945
# -0.101233333333
# -1.4742
# 0.240666666667
# 0.920266666667
# 0.686666666667
# -1.5553
# 1.43423333333
# 1.96996666667
# 0.6412
# -0.319566666667
# 1.94876666667
# 0.528633333333
# -0.603366666667
# -0.488666666667
# -0.103
# 0.221633333333
# 0.539233333333
# -0.407066666667
# 0.25
# -0.822866666667
# 1.44866666667
# -1.23553333333
# 0.1164
# -0.5163
# -0.272566666667
# 0.0662666666667
# 0.456333333333
# 0.310933333333
# -0.1976
# -1.56143333333
# -0.6135
# 0.8266
# 1.65846666667
# -1.11276666667
# -0.148766666667
# 0.251433333333
# -0.581833333333
# -0.197833333333
# -0.0929333333333
# -0.651466666667
# 1.4397
# -0.353066666667
# 0.523233333333
# -0.365533333333
# -0.5711
# 0.438666666667
# -0.0789
# 1.22953333333
# -0.5038
# -0.645666666667
# -0.0751
# 0.1905
# 0.552333333333
# -0.8225
# 0.148366666667
# -0.668933333333
# -0.716066666667
# 0.842033333333
# -0.142166666667
# -0.463866666667
# -0.181333333333
# 1.7276
# 0.534666666667
# -0.885033333333
# 0.411933333333
# -0.495633333333
# -0.439266666667
# -0.584966666667
# 2.01956666667
# 0.8602
# -1.08393333333
# 0.512533333333
# -0.964466666667
# -0.216233333333
# -1.03736666667
# -0.738833333333
# 2.41873333333
# -0.3708
# 0.388
# -0.483233333333
# -0.4404
# 0.334666666667
# -0.478633333333
# -0.242933333333
# -0.441733333333
# 0.443566666667
# -0.8627
# -1.0328
# -0.8284
# -0.745533333333
# -1.4243
# 0.680366666667
# -0.2837
# -0.303066666667
# 2.7447
# -1.96636666667
# 0.0316666666667
# -0.3493
# -0.145066666667
# 0.296966666667
# 0.0928666666667
# 1.40503333333
# 1.1611
# -0.705366666667
# -1.13106666667
# 0.0605
# 1.0766
# -0.172266666667
# 0.1671
# -0.258266666667
# 0.714333333333
# -0.957266666667
# -0.339
# 0.578366666667
# -0.00669999999999
# -0.9702
# 0.158766666667
# 1.3446
# -0.1506
# 0.578466666667
# -0.336533333333
# 0.401566666667
# -1.90043333333
# -1.08776666667
# 1.0472
# 0.370866666667
# -1.11426666667
# 0.279566666667
# -0.532066666667
# 0.401666666667
# -1.35406666667
# 2.22733333333
# -0.712733333333
# 0.571966666667
# -0.105366666667
# -0.250066666667
# 0.3013
# -0.0351
# -0.1843
# 0.3532
# 0.5798
# 0.0613666666667
# -0.545933333333
# -0.432033333333
# 0.420066666667
# 0.3141
# 0.9776
# 0.1796
# -0.414866666667
# -0.9447
# 1.23336666667
# 0.857466666667
# -0.8036
# -1.36796666667
# -0.543533333333
# -0.0596333333333
# 0.7354
# 0.1137
# -0.230766666667
# -1.16223333333
# -0.193566666667
# -1.42116666667
# -0.106666666667
# -1.13626666667
# -1.34193333333
# -0.9635
# -0.234333333333
# -0.683466666667
# -0.561066666667
# 0.134
# -0.7881
# 0.753533333333
# 0.2219
# 0.0416333333333
# -1.3509
# 0.1998
# -0.226566666667
# -0.6031
# 0.0771666666667
# -0.809333333333
# -1.1503
# 0.265566666667
# -0.3949
# -0.439466666667
# 0.5298
# -0.874033333333
# 0.399966666667
# -2.08816666667
# 0.717366666667
# 1.08833333333
# 1.08706666667
# 1.80243333333
# -0.6653
# 0.276533333333
# 1.7993
# 0.889733333333
# 0.1482
# -0.0236333333333
# 0.792166666667
# -0.704333333333
# 0.798666666667
# 1.03176666667
# 1.519
# -1.12913333333
# 0.578766666667
# -1.1916
# -0.0526666666667
# 0.315966666667
# -1.23703333333
# 0.7522
# -0.658066666667
# 0.0786
# -0.226
# -0.436066666667
# 0.685633333333
# 1.23226666667
# 0.941833333333
# 0.335333333333
# 1.16283333333
# -0.286366666667
# -0.333066666667
# 0.178733333333
# 0.162966666667
# 0.628033333333
# -1.0191
# 1.4842
# -2.01853333333
# 0.738333333333
# -0.294766666667
# 0.903566666667
# 2.12403333333
# -0.4709
# -1.03766666667
# 0.288866666667
# -0.790733333333
# 0.198133333333
# -0.341666666667
# -1.47166666667
# 0.3908
# -0.344933333333
# 1.0

# %%
def list_incorrect(w, X, y):
    '''
    w is the sparse weight vector
    X is the vector needed to be classified
    y is the true label
    --------------------------
    incorrect_list is the percent of the wrong classifiation
    '''
    incorrect_list = []
    weight_list = []
    N = len(X)
    index = []
    y_p = []
    y_true = []
    wx = []
    for i in range(N):
        yy = dotProduct(w, X[i]) 
        if yy > 0:
            yy = 1
        else:
            yy = -1
        
        if yy !=y[i]:
            incorrect_list.append(X[i])
            index.append(i)
            y_p.append(yy)
            y_true.append(y[i])
            wx.append(dotProduct(w, X[i]))
            
    return incorrect_list, index, y_p, y_true,wx

# %%
w = pegasos_svm_change(X_train, y_train, Lambda=10, num_iter=50)
incorrect, index, yy, yt, wx = list_incorrect(w, X_valid, y_valid)
# Out:
# The time of the 1 epoch is 0.36093471200729255
# The time of the 2 epoch is 0.3800632070051506
# The time of the 3 epoch is 0.34980500300298445
# The time of the 4 epoch is 0.3510934150108369
# The time of the 5 epoch is 0.35006773300119676
# The time of the 6 epoch is 0.35433160699903965
# The time of the 7 epoch is 0.3476005609991262
# The time of the 8 epoch is 0.3579837500001304
# The time of the 9 epoch is 0.34953105299791787
# The time of the 10 epoch is 0.3536858480074443
# The time of the 11 epoch is 0.35037964599905536
# The time of the 12 epoch is 0.37427950400160626
# The time of the 13 epoch is 0.3482534720096737
# The time of the 14 epoch is 0.3634093220025534
# The time of the 15 epoch is 0.344598550000228
# The time of the 16 epoch is 0.35087431999272667
# The time of the 17 epoch is 0.35113818899844773
# The time of the 18 epoch is 0.3521775859990157
# The time of the 19 epoch is 0.3813792479922995
# The time of the 20 epoch is 0.406831714004511
# The time of the 21 epoch is 0.3749771949951537
# The time of the 22 epoch is 0.3658263069955865
# The time of the 23 epoch is 0.36404440000478644
# The time of the 24 epoch is 0.35996498398890253
# The time of the 25 epoch is 0.4840512789960485
# The time of the 26 epoch is 0.358379771001637
# The time of the 27 epoch is 0.36824317400169093
# The time of the 28 epoch is 0.5726886000047671
# The time of the 29 epoch is 0.46315082799992524
# The time of the 30 epoch is 0.3643036500143353
# The time of the 31 epoch is 0.470996477000881
# The time of the 32 epoch is 0.5112373449956067
# The time of the 33 epoch is 0.5444431249925401
# The time of the 34 epoch is 0.34871175400621723
# The time of the 35 epoch is 0.3505805939930724
# The time of the 36 epoch is 0.3501159899897175
# The time of the 37 epoch is 0.3442465640109731
# The time of the 38 epoch is 0.358272412995575
# The time of the 39 epoch is 0.36967705900315195
# The time of the 40 epoch is 0.3463235880044522
# The time of the 41 epoch is 0.35548555199056864
# The time of the 42 epoch is 0.3591370629874291
# The time of the 43 epoch is 0.3689231739990646
# The time of the 44 epoch is 0.35361519700381905
# The time of the 45 epoch is 0.36481294699478894
# The time of the 46 epoch is 0.34377378900535405
# The time of the 47 epoch is 0.35352323501138017
# The time of the 48 epoch is 0.3483452860091347
# The time of the 49 epoch is 0.3605584660108434
# The time of the 50 epoch is 0.35113702999660745
# 1.3333333333333252e-05

# %%
percent_error(w, X_valid, y_valid)
# Out:
# 0.286

# %%
w_wrong = {}
for k,v in w.items():
    if abs(v)>=0.01:
        w_wrong[k] = w.get(k, 0) + v
        
w_high = pd.DataFrame(w_wrong,index=range(len(w_wrong))).T
w_high = w_high[0]
w_high
# Out:
# !       -0.034757
# ?       -0.056659
# also     0.041859
# bad     -0.066707
# best     0.029917
# film     0.049779
# great    0.029275
# life     0.055275
# love     0.022173
# many     0.024715
# movie   -0.059741
# plot    -0.027611
# story    0.022152
# well     0.024776
# world    0.028056
# worst   -0.021296
# Name: 0, dtype: float64

# %%
len(incorrect), len(yy), len(yt), len(index),len(wx)
# Out:
# (143, 143, 143, 143, 143)

# %%
w["wedding"]
# Out:
# 0.0007999999999999962

# %%
import pandas as pd
summ = pd.DataFrame(index)
summ['incorr'] = incorrect
summ['y_predicted'] = yy
summ['y_true'] = yt
summ['w*x'] = wx
summ.to_csv('/Users/twff/Downloads/machine_learning/hw/hw3-sentiment/wronglist.csv')

# %%
w_high
# Out:
# 1997               0.266667
# 7                  0.346667
# 710                0.326667
# 8                  0.293333
# 810                0.420000
# _shaft_            0.233333
# abby               0.380000
# able               0.453333
# abortion           0.226667
# above              0.220000
# absolutely         0.260000
# academy            0.213333
# adult              0.206667
# adults             0.206667
# adventure          0.346667
# affleck            0.333333
# africanamerican    0.213333
# after              0.413333
# against            0.206667
# age                0.366667
# ago                0.486667
# agrees             0.233333
# alex               0.326667
# alice              0.226667
# alien              0.400000
# aliens             0.360000
# allen              0.320000
# allows             0.386667
# almost             0.360000
# also               0.980000
#                      ...
# white              0.253333
# who's              0.226667
# whole              0.206667
# whoopi             0.220000
# will               0.900000
# williamson's       0.206667
# winds              0.240000
# windsor            0.260000
# winslet            0.280000
# wish               0.280000
# witherspoon        0.266667
# witty              0.413333
# won't              0.426667
# wonderful          0.486667
# wonderfully        0.660000
# wondering          0.253333
# woo's              0.213333
# woody              0.326667
# working            0.273333
# works              0.406667
# world              0.993333
# wound              0.220000
# wright             0.220000
# xfiles             0.326667
# yet                0.813333
# you                1.120000
# your               0.280000
# zero               0.313333
# zero's             0.233333
# zorro              0.300000
# Name: 0, dtype: float64

# %%
Xb_train  = []
yb_train = []
bigram_data = []
i=0
j=0
while i < len(training_data):
    bigram = []
    i +=1
    #print(i)
    while j < (len(training_data[1])-1):
        bigram.append((training_data[i][j],training_data[i][j+1]))
        #print(j)
        j+=1
    bigram_data.append(bigram)

# %%
Xb_valid  = []
yb_valid = []
bigram_data_test = []
i=0
j=0
while i < len(validation_data):
    bigram = []
    i +=1
    #print(i)
    while j < (len(validation_data[1])-1):
        bigram.append((validation_data[i][j],validation_data[i][j+1]))
        #print(j)
        j+=1
    bigram_data_test.append(bigram)

# %%
for i in range(len(training_data)):
    words, label = bag_of_words(bigram_data[i])
    Xb_train.append(words)
    yb_train.append(label)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-7421efdafb66> in <module>()
#       1 for i in range(len(training_data)):
# ----> 2     words, label = bag_of_words(bigram_data[i])
#       3     Xb_train.append(words)
#       4     yb_train.append(label)
#       5
#
# <ipython-input-9-182c7fffbf1b> in bag_of_words(words)
#      12     words_stopfree = [w for w in words if w not in stop]
#      13     count = Counter(words_stopfree[:-1])
# ---> 14     label = words[-1]
#      15     return count, label
#
# IndexError: list index out of range

# %%
X_valid  = []
y_valid = []
for i in range(len(validation_data)):
    words, label = bag_of_words(validation_data[i])
    X_valid.append(words)
    y_valid.append(label)

# %%
n = len(X_valid)
w = pegasos_svm_change(X_train, y_train, Lambda=10, num_iter=20)
error = percent_error(w, X_valid, y_valid)
std_error = ((1-error)*error)/n
